# %% [markdown]
# #  Corona vaccine progress
# version 0.91 created by Magnus Sälgö [twitter](https://twitter.com/salgo60), [Linked in](https://www.linkedin.com/in/magnus-s%C3%A4lg%C3%B6-148890/)
#
# * [this Notebook](https://github.com/salgo60/CoronaVaccinationCheck/blob/master/Check%20Corona%20Vaccination.ipynb) / [repository](https://github.com/salgo60/CoronaVaccinationCheck)
#
# * read the data from [github.com/owid/covid-19-data...vaccinations/country_data](https://github.com/owid/covid-19-data/tree/master/public/data/vaccinations/country_data) and Wikidata
#   * Data is reported cummulated for United Kingdom but also subnational data England, Scotland, Northern Ireland, Wales see [issue 228](https://github.com/owid/covid-19-data/issues/228)
#      * subnational data have been published quite irregularly so far ==> we filter them out

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2021-01-13 12:56:41.972610

# %%
import pandas as pd
GITHUB_directory = "https://api.github.com/repos/owid/covid-19-data/contents/public/data/vaccinations/country_data"  
countries = pd.read_json(GITHUB_directory)  
listcountries = []
for index,row in countries.iterrows():
    df = pd.read_csv(row["download_url"])
    listcountries.append(df)
    
allCountriesGitHub = pd.concat(listcountries, axis=0, ignore_index=True)

# %%
GITHUB_location_csv = "https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/locations.csv"  
countries_csv = pd.read_csv(GITHUB_location_csv)

# %%
countries_csv
# Out:
#                 location iso_code  ...                                        source_name                                     source_website
# 0              Argentina      ARG  ...                            Government of Argentina  https://www.argentina.gob.ar/noticias/ya-se-ap...
# 1                Austria      AUT  ...                                 Ministry of Health  https://info.gesundheitsministerium.gv.at/data...
# 2                Bahrain      BHR  ...                                 Ministry of Health  https://twitter.com/MOH_Bahrain/status/1349090...
# 3                Belgium      BEL  ...                   Government vaccination taskforce  https://www.lalibre.be/belgique/societe/vaccin...
# 4               Bulgaria      BGR  ...                                 Ministry of Health               https://coronavirus.bg/bg/statistika
# 5                 Canada      CAN  ...            COVID-19 Canada Open Data Working Group         https://github.com/ishaberry/Covid19Canada
# 6                  Chile      CHL  ...    Department of Statistics and Health Information                            https://deis.minsal.cl/
# 7                  China      CHN  ...                         National Health Commission  http://www.scio.gov.cn/xwfbh/xwbfbh/wqfbh/4468...
# 8             Costa Rica      CRI  ...                         National Health Commission  https://www.ccss.sa.cr/noticias/servicios_noti...
# 9                Croatia      HRV  ...                                 Ministry of Health  https://www.jutarnji.hr/vijesti/hrvatska/cijel...
# 10                Cyprus      CYP  ...                                 Ministry of Health  https://gr.euronews.com/2021/01/11/kypros-pyli...
# 11               Czechia      CZE  ...                                 Ministry of Health       https://onemocneni-aktualne.mzcr.cz/covid-19
# 12               Denmark      DNK  ...                             Statens Serum Institut  https://covid19.ssi.dk/overvagningsdata/vaccin...
# 13               England      NaN  ...                   Government of the United Kingdom  https://coronavirus.data.gov.uk/details/health...
# 14               Estonia      EST  ...                              National Health Board              https://www.terviseamet.ee/et/uudised
# 15               Finland      FIN  ...                          THL via Helsingin Sanomat  https://github.com/HS-Datadesk/koronavirus-avo...
# 16                France      FRA  ...                                 Ministry of Health  https://www.data.gouv.fr/fr/datasets/donnees-r...
# 17               Germany      DEU  ...                               Robert Koch Institut  https://www.rki.de/DE/Content/InfAZ/N/Neuartig...
# 18             Gibraltar      GIB  ...                            Government of Gibraltar  https://www.gibraltar.gov.gi/press-releases/da...
# 19                Greece      GRC  ...                                 Ministry of Health      https://www.data.gov.gr/datasets/mdg_emvolio/
# 20                Guinea      GIN  ...                    National Health Security Agency  https://apnews.com/article/cabinets-health-gui...
# 21               Hungary      HUN  ...                              Government of Hungary  https://koronavirus.gov.hu/cikkek/1358-fovel-e...
# 22               Iceland      ISL  ...                              Directorate of Health  https://www.ruv.is/frett/2020/12/30/4875-lands...
# 23               Ireland      IRL  ...                           Health Service Executive  https://twitter.com/newschambers/status/134870...
# 24                Israel      ISR  ...                               Government of Israel  https://datadashboard.health.gov.il/COVID-19/g...
# 25                 Italy      ITA  ...  Extraordinary commissioner for the Covid-19 em...  https://github.com/italia/covid19-opendata-vac...
# 26                Kuwait      KWT  ...                                 Ministry of Health  https://alqabas.com/article/5828928-2500-شخص-ح...
# 27                Latvia      LVA  ...                            National Health Service  http://www.vmnvd.gov.lv/lv/covid-19/1486-vakci...
# 28             Lithuania      LTU  ...                                 Ministry of Health  https://ls-osp-sdg.maps.arcgis.com/apps/opsdas...
# 29            Luxembourg      LUX  ...                           Government of Luxembourg  https://download.data.public.lu/resources/covi...
# 30                 Malta      MLT  ...                                 Ministry of Health  https://timesofmalta.com/articles/view/1400-re...
# 31                Mexico      MEX  ...                                Secretary of Health  https://twitter.com/NTelevisa_com/status/13491...
# 32           Netherlands      NLD  ...  National Institute for Public Health and the E...        https://www.youtube.com/watch?v=HJyszQXZIqA
# 33      Northern Ireland      NaN  ...                   Government of the United Kingdom  https://coronavirus.data.gov.uk/details/health...
# 34                Norway      NOR  ...               Norwegian Institute of Public Health  https://www.fhi.no/sv/vaksine/koronavaksinasjo...
# 35                  Oman      OMN  ...                                 Ministry of Health  https://twitter.com/OmaniMOH/status/1349258028...
# 36                Poland      POL  ...                                 Ministry of Health  https://twitter.com/szczepimysie/status/134928...
# 37              Portugal      PRT  ...                            National Health Service  https://esriportugal.maps.arcgis.com/apps/opsd...
# 38               Romania      ROU  ...                              Government of Romania  https://vaccinare-covid.gov.ro/comunicate-ofic...
# 39                Russia      RUS  ...                               Government of Russia                   https://tass.com/society/1241979
# 40          Saudi Arabia      SAU  ...                         Ministry of Hajj and Umrah                              https://coronamap.sa/
# 41              Scotland      NaN  ...                   Government of the United Kingdom  https://coronavirus.data.gov.uk/details/health...
# 42                Serbia      SRB  ...                               Government of Serbia  https://www.srbija.gov.rs/vest/en/166035/preco...
# 43              Slovakia      SVK  ...                                 Ministry of Health  https://korona.gov.sk/koronavirus-na-slovensku...
# 44              Slovenia      SVN  ...  National Institute of Public Health, via Sledi...                 https://covid-19.sledilnik.org/en/
# 45                 Spain      ESP  ...                                 Ministry of Health  https://www.mscbs.gob.es/profesionales/saludPu...
# 46                Sweden      SWE  ...                     Public Health Agency of Sweden  https://www.folkhalsomyndigheten.se/smittskydd...
# 47  United Arab Emirates      ARE  ...  National Emergency Crisis and Disaster Managem...                       https://twitter.com/NCEMAUAE
# 48        United Kingdom      GBR  ...                   Government of the United Kingdom  https://coronavirus.data.gov.uk/details/health...
# 49         United States      USA  ...         Centers for Disease Control and Prevention  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 50                 Wales      NaN  ...                   Government of the United Kingdom  https://coronavirus.data.gov.uk/details/health...
#
# [51 rows x 6 columns]

# %%
#order by last updated ascending
countries_csv = countries_csv.sort_values(by=['last_observation_date'],ascending=False)
#countries_csv.reindex(["location"])
countries_csv.reset_index(drop=True, inplace=True)
countries_csv
# Out:
#                 location iso_code  ...                                        source_name                                     source_website
# 0                Estonia      EST  ...                              National Health Board              https://www.terviseamet.ee/et/uudised
# 1               Bulgaria      BGR  ...                                 Ministry of Health               https://coronavirus.bg/bg/statistika
# 2                 Israel      ISR  ...                               Government of Israel  https://datadashboard.health.gov.il/COVID-19/g...
# 3                Hungary      HUN  ...                              Government of Hungary  https://koronavirus.gov.hu/cikkek/1358-fovel-e...
# 4                   Oman      OMN  ...                                 Ministry of Health  https://twitter.com/OmaniMOH/status/1349258028...
# 5                 Poland      POL  ...                                 Ministry of Health  https://twitter.com/szczepimysie/status/134928...
# 6                 Mexico      MEX  ...                                Secretary of Health  https://twitter.com/NTelevisa_com/status/13491...
# 7                 Latvia      LVA  ...                            National Health Service  http://www.vmnvd.gov.lv/lv/covid-19/1486-vakci...
# 8            Netherlands      NLD  ...  National Institute for Public Health and the E...        https://www.youtube.com/watch?v=HJyszQXZIqA
# 9                Austria      AUT  ...                                 Ministry of Health  https://info.gesundheitsministerium.gv.at/data...
# 10                Greece      GRC  ...                                 Ministry of Health      https://www.data.gov.gr/datasets/mdg_emvolio/
# 11             Gibraltar      GIB  ...                            Government of Gibraltar  https://www.gibraltar.gov.gi/press-releases/da...
# 12                France      FRA  ...                                 Ministry of Health  https://www.data.gouv.fr/fr/datasets/donnees-r...
# 13               Finland      FIN  ...                          THL via Helsingin Sanomat  https://github.com/HS-Datadesk/koronavirus-avo...
# 14                 Italy      ITA  ...  Extraordinary commissioner for the Covid-19 em...  https://github.com/italia/covid19-opendata-vac...
# 15               Romania      ROU  ...                              Government of Romania  https://vaccinare-covid.gov.ro/comunicate-ofic...
# 16              Slovenia      SVN  ...  National Institute of Public Health, via Sledi...                 https://covid-19.sledilnik.org/en/
# 17                 Spain      ESP  ...                                 Ministry of Health  https://www.mscbs.gob.es/profesionales/saludPu...
# 18  United Arab Emirates      ARE  ...  National Emergency Crisis and Disaster Managem...                       https://twitter.com/NCEMAUAE
# 19                Canada      CAN  ...            COVID-19 Canada Open Data Working Group         https://github.com/ishaberry/Covid19Canada
# 20         United States      USA  ...         Centers for Disease Control and Prevention  https://covid.cdc.gov/covid-data-tracker/#vacc...
# 21               Bahrain      BHR  ...                                 Ministry of Health  https://twitter.com/MOH_Bahrain/status/1349090...
# 22             Lithuania      LTU  ...                                 Ministry of Health  https://ls-osp-sdg.maps.arcgis.com/apps/opsdas...
# 23          Saudi Arabia      SAU  ...                         Ministry of Hajj and Umrah                              https://coronamap.sa/
# 24              Scotland      NaN  ...                   Government of the United Kingdom  https://coronavirus.data.gov.uk/details/health...
# 25              Slovakia      SVK  ...                                 Ministry of Health  https://korona.gov.sk/koronavirus-na-slovensku...
# 26                Norway      NOR  ...               Norwegian Institute of Public Health  https://www.fhi.no/sv/vaksine/koronavaksinasjo...
# 27      Northern Ireland      NaN  ...                   Government of the United Kingdom  https://coronavirus.data.gov.uk/details/health...
# 28        United Kingdom      GBR  ...                   Government of the United Kingdom  https://coronavirus.data.gov.uk/details/health...
# 29                 Wales      NaN  ...                   Government of the United Kingdom  https://coronavirus.data.gov.uk/details/health...
# 30               Denmark      DNK  ...                             Statens Serum Institut  https://covid19.ssi.dk/overvagningsdata/vaccin...
# 31               Ireland      IRL  ...                           Health Service Executive  https://twitter.com/newschambers/status/134870...
# 32               Germany      DEU  ...                               Robert Koch Institut  https://www.rki.de/DE/Content/InfAZ/N/Neuartig...
# 33               England      NaN  ...                   Government of the United Kingdom  https://coronavirus.data.gov.uk/details/health...
# 34            Luxembourg      LUX  ...                           Government of Luxembourg  https://download.data.public.lu/resources/covi...
# 35                Serbia      SRB  ...                               Government of Serbia  https://www.srbija.gov.rs/vest/en/166035/preco...
# 36                Sweden      SWE  ...                     Public Health Agency of Sweden  https://www.folkhalsomyndigheten.se/smittskydd...
# 37                Cyprus      CYP  ...                                 Ministry of Health  https://gr.euronews.com/2021/01/11/kypros-pyli...
# 38                 China      CHN  ...                         National Health Commission  http://www.scio.gov.cn/xwfbh/xwbfbh/wqfbh/4468...
# 39               Croatia      HRV  ...                                 Ministry of Health  https://www.jutarnji.hr/vijesti/hrvatska/cijel...
# 40            Costa Rica      CRI  ...                         National Health Commission  https://www.ccss.sa.cr/noticias/servicios_noti...
# 41             Argentina      ARG  ...                            Government of Argentina  https://www.argentina.gob.ar/noticias/ya-se-ap...
# 42              Portugal      PRT  ...                            National Health Service  https://esriportugal.maps.arcgis.com/apps/opsd...
# 43               Belgium      BEL  ...                   Government vaccination taskforce  https://www.lalibre.be/belgique/societe/vaccin...
# 44               Czechia      CZE  ...                                 Ministry of Health       https://onemocneni-aktualne.mzcr.cz/covid-19
# 45                 Chile      CHL  ...    Department of Statistics and Health Information                            https://deis.minsal.cl/
# 46                 Malta      MLT  ...                                 Ministry of Health  https://timesofmalta.com/articles/view/1400-re...
# 47                Russia      RUS  ...                               Government of Russia                   https://tass.com/society/1241979
# 48                Guinea      GIN  ...                    National Health Security Agency  https://apnews.com/article/cabinets-health-gui...
# 49               Iceland      ISL  ...                              Directorate of Health  https://www.ruv.is/frett/2020/12/30/4875-lands...
# 50                Kuwait      KWT  ...                                 Ministry of Health  https://alqabas.com/article/5828928-2500-شخص-ح...
#
# [51 rows x 6 columns]

# %% [markdown]
# ## Latest reported

# %%
# merge allCountriesGitHub with all Countries_csv
allCountries = pd.merge(allCountriesGitHub,countries_csv,how='outer',on="location",indicator=True)
# Show 15 latest sorted by dates
allCountries.sort_values(by=['date'],ascending=False)[0:20]
# Out:
#                  location        date  ...                                     source_website _merge
# 328                  Oman  2021-01-13  ...  https://twitter.com/OmaniMOH/status/1349258028...   both
# 343                Poland  2021-01-13  ...  https://twitter.com/szczepimysie/status/134928...   both
# 195               Hungary  2021-01-13  ...  https://koronavirus.gov.hu/cikkek/1358-fovel-e...   both
# 44               Bulgaria  2021-01-13  ...               https://coronavirus.bg/bg/statistika   both
# 134               Estonia  2021-01-13  ...              https://www.terviseamet.ee/et/uudised   both
# 226                Israel  2021-01-13  ...  https://datadashboard.health.gov.il/COVID-19/g...   both
# 141               Finland  2021-01-12  ...  https://github.com/HS-Datadesk/koronavirus-avo...   both
# 147                France  2021-01-12  ...  https://www.data.gouv.fr/fr/datasets/donnees-r...   both
# 327                  Oman  2021-01-12  ...  https://twitter.com/OmaniMOH/status/1349258028...   both
# 32                Bahrain  2021-01-12  ...  https://twitter.com/MOH_Bahrain/status/1349090...   both
# 43               Bulgaria  2021-01-12  ...               https://coronavirus.bg/bg/statistika   both
# 133               Estonia  2021-01-12  ...              https://www.terviseamet.ee/et/uudised   both
# 166             Gibraltar  2021-01-12  ...  https://www.gibraltar.gov.gi/press-releases/da...   both
# 287                Mexico  2021-01-12  ...  https://twitter.com/NTelevisa_com/status/13491...   both
# 342                Poland  2021-01-12  ...  https://twitter.com/szczepimysie/status/134928...   both
# 182                Greece  2021-01-12  ...      https://www.data.gov.gr/datasets/mdg_emvolio/   both
# 294           Netherlands  2021-01-12  ...        https://www.youtube.com/watch?v=HJyszQXZIqA   both
# 408  United Arab Emirates  2021-01-12  ...                       https://twitter.com/NCEMAUAE   both
# 194               Hungary  2021-01-12  ...  https://koronavirus.gov.hu/cikkek/1358-fovel-e...   both
# 256                Latvia  2021-01-12  ...  http://www.vmnvd.gov.lv/lv/covid-19/1486-vakci...   both
#
# [20 rows x 13 columns]

# %%
#Countries in list
allCountries["location"].value_counts()
# Out:
# Canada                  30
# Israel                  26
# Bahrain                 21
# Italy                   17
# Greece                  16
# Romania                 16
# Germany                 16
# Estonia                 16
# Denmark                 16
# Oman                    15
# Poland                  15
# Lithuania               14
# United States           14
# Mexico                  14
# Norway                  13
# Hungary                 12
# Latvia                  12
# Slovenia                10
# Bulgaria                10
# Austria                  8
# Chile                    7
# Finland                  7
# Netherlands              7
# United Arab Emirates     7
# Wales                    6
# France                   6
# Portugal                 6
# Spain                    6
# Croatia                  6
# Northern Ireland         6
# Scotland                 6
# United Kingdom           5
# England                  5
# Slovakia                 5
# Ireland                  4
# Argentina                4
# Sweden                   3
# Gibraltar                3
# Costa Rica               3
# Russia                   3
# China                    3
# Czechia                  2
# Saudi Arabia             2
# Belgium                  2
# Luxembourg               2
# Cyprus                   2
# Serbia                   1
# Kuwait                   1
# Malta                    1
# Iceland                  1
# Guinea                   1
# Name: location, dtype: int64

# %%
allCountries.groupby(["location", "vaccine"]).size()
# Out:
# location              vaccine
# Argentina             Sputnik V                               4
# Austria               Pfizer/BioNTech                         8
# Bahrain               Pfizer/BioNTech, Sinopharm             21
# Belgium               Pfizer/BioNTech                         2
# Bulgaria              Pfizer/BioNTech                        10
# Canada                Moderna, Pfizer/BioNTech               13
#                       Pfizer/BioNTech                        17
# Chile                 Pfizer/BioNTech                         7
# China                 CNBG, Sinovac                           3
# Costa Rica            Pfizer/BioNTech                         3
# Croatia               Pfizer/BioNTech                         6
# Cyprus                Pfizer/BioNTech                         2
# Czechia               Pfizer/BioNTech                         2
# Denmark               Pfizer/BioNTech                        16
# England               Oxford/AstraZeneca, Pfizer/BioNTech     2
#                       Pfizer/BioNTech                         3
# Estonia               Pfizer/BioNTech                        16
# Finland               Pfizer/BioNTech                         7
# France                Pfizer/BioNTech                         6
# Germany               Pfizer/BioNTech                        16
# Gibraltar             Pfizer/BioNTech                         3
# Greece                Pfizer/BioNTech                        16
# Guinea                Sputnik V                               1
# Hungary               Pfizer/BioNTech                        12
# Iceland               Pfizer/BioNTech                         1
# Ireland               Pfizer/BioNTech                         4
# Israel                Pfizer/BioNTech                        26
# Italy                 Pfizer/BioNTech                        17
# Kuwait                Pfizer/BioNTech                         1
# Latvia                Pfizer/BioNTech                        12
# Lithuania             Pfizer/BioNTech                        14
# Luxembourg            Pfizer/BioNTech                         2
# Malta                 Pfizer/BioNTech                         1
# Mexico                Pfizer/BioNTech                        14
# Netherlands           Pfizer/BioNTech                         7
# Northern Ireland      Oxford/AstraZeneca, Pfizer/BioNTech     2
#                       Pfizer/BioNTech                         4
# Norway                Pfizer/BioNTech                        13
# Oman                  Pfizer/BioNTech                        15
# Poland                Pfizer/BioNTech                        15
# Portugal              Pfizer/BioNTech                         6
# Romania               Pfizer/BioNTech                        16
# Russia                Sputnik V                               3
# Saudi Arabia          Pfizer/BioNTech                         2
# Scotland              Oxford/AstraZeneca, Pfizer/BioNTech     2
#                       Pfizer/BioNTech                         4
# Serbia                Pfizer/BioNTech                         1
# Slovakia              Pfizer/BioNTech                         5
# Slovenia              Pfizer/BioNTech                        10
# Spain                 Pfizer/BioNTech                         6
# Sweden                Pfizer/BioNTech                         3
# United Arab Emirates  Pfizer/BioNTech, Sinopharm              7
# United Kingdom        Oxford/AstraZeneca, Pfizer/BioNTech     2
#                       Pfizer/BioNTech                         3
# United States         Moderna, Pfizer/BioNTech               12
#                       Pfizer/BioNTech                         2
# Wales                 Oxford/AstraZeneca, Pfizer/BioNTech     2
#                       Pfizer/BioNTech                         4
# dtype: int64

# %%
allCountries['date'] = allCountries['date'].astype('datetime64[ns]')   

# Filter away Wales , England, Scotland see above and [issue 228](https://github.com/owid/covid-19-data/issues/228)
list_of_countries_to_delete = ["England","Northern Ireland","Scotland","Wales"]

allCountriesFiltered = allCountries[~allCountries["location"].isin(list_of_countries_to_delete)]
allCountriesFiltered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 411 entries, 0 to 427
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   location                 411 non-null    object
#  1   date                     411 non-null    datetime64[ns]
#  2   vaccine                  411 non-null    object
#  3   source_url               411 non-null    object
#  4   total_vaccinations       411 non-null    int64
#  5   people_vaccinated        407 non-null    float64
#  6   people_fully_vaccinated  411 non-null    int64
#  7   iso_code                 411 non-null    object
#  8   vaccines                 411 non-null    object
#  9   last_observation_date    411 non-null    object
#  10  source_name              411 non-null    object
#  11  source_website           411 non-null    object
#  12  _merge                   411 non-null    category
# dtypes: category(1), datetime64[ns](1), float64(1), int64(2), object(8)
# memory usage: 42.2+ KB

# %%
#Reported numbers are accumulated --> get latest
plotLatestCountries = allCountriesFiltered.sort_values(by=['date'],ascending=False) \
    [['total_vaccinations','location','vaccine','iso_code']].groupby('location').apply(lambda x: x.head(1))
plotLatestCountries = plotLatestCountries.set_index('location')
worldtotal_vaccinations_str = '{:,}'.format(plotLatestCountries.sum()["total_vaccinations"]).replace(',', ' ')
print(worldtotal_vaccinations_str, plotLatestCountries.shape)
# Out:
# 29 493 847 (47, 3)

# %% [markdown]
# ## Charts

# %%
# plot all values = allCountriesFiltered
# %matplotlib inline    
import matplotlib.pyplot as plt   
import seaborn as sns
plt.rcParams.update(plt.rcParamsDefault) 
plt.rcParams['figure.figsize'] = (15.0, 8.0)

sns.lineplot(data=allCountriesFiltered, x="date", y="total_vaccinations", hue="location" )
plt.title("Vaccinations per countries (million) - " + start_time.strftime('%Y %m %d'))
plt.suptitle("Total Vaccination: " + worldtotal_vaccinations_str  + " - " + start_time.strftime('%Y %m %d'),y=0)

plt.savefig('images/Corona_Line.png',bbox_inches='tight')  
plt.show()

# %%
allCountriesFiltered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 411 entries, 0 to 427
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   location                 411 non-null    object
#  1   date                     411 non-null    datetime64[ns]
#  2   vaccine                  411 non-null    object
#  3   source_url               411 non-null    object
#  4   total_vaccinations       411 non-null    int64
#  5   people_vaccinated        407 non-null    float64
#  6   people_fully_vaccinated  411 non-null    int64
#  7   iso_code                 411 non-null    object
#  8   vaccines                 411 non-null    object
#  9   last_observation_date    411 non-null    object
#  10  source_name              411 non-null    object
#  11  source_website           411 non-null    object
#  12  _merge                   411 non-null    category
# dtypes: category(1), datetime64[ns](1), float64(1), int64(2), object(8)
# memory usage: 42.2+ KB

# %%
# Resample dates Forward filling and sum

#allCountriesFiltered
#grouper = allCountriesFiltered.groupby([pd.Grouper(key="date",freq='1D'), 'location']).mean()

# %%
# Plot filtered
plt.rcParams.update(plt.rcParamsDefault) 
plt.rcParams['figure.figsize'] = (5, 5)
plotLatestCountries["total_vaccinations"].plot( y='location',kind = 'pie') 
plt.title("Vaccination per countries - " + start_time.strftime('%Y %m %d'))
plt.suptitle("Total Vaccination: " + worldtotal_vaccinations_str ,y=1)
plt.savefig('images/Corona_VaccinationperCountry.png')  
plt.show()

# %%
plotLatestCountries.sort_values(by='total_vaccinations',ascending=False)
# Out:
#                       total_vaccinations                              vaccine iso_code
# location
# United States                    9327138             Moderna, Pfizer/BioNTech      USA
# China                            9000000                        CNBG, Sinovac      CHN
# United Kingdom                   2843815  Oxford/AstraZeneca, Pfizer/BioNTech      GBR
# Israel                           1933294                      Pfizer/BioNTech      ISR
# United Arab Emirates             1275652           Pfizer/BioNTech, Sinopharm      ARE
# Italy                             800730                      Pfizer/BioNTech      ITA
# Russia                            800000                            Sputnik V      RUS
# Germany                           688782                      Pfizer/BioNTech      DEU
# Spain                             488122                      Pfizer/BioNTech      ESP
# Canada                            388493             Moderna, Pfizer/BioNTech      CAN
# Poland                            309620                      Pfizer/BioNTech      POL
# France                            189834                      Pfizer/BioNTech      FRA
# Saudi Arabia                      178337                      Pfizer/BioNTech      SAU
# Romania                           140447                      Pfizer/BioNTech      ROU
# Denmark                           117104                      Pfizer/BioNTech      DNK
# Argentina                         107542                            Sputnik V      ARG
# Bahrain                            97776           Pfizer/BioNTech, Sinopharm      BHR
# Mexico                             92879                      Pfizer/BioNTech      MEX
# Hungary                            86929                      Pfizer/BioNTech      HUN
# Sweden                             79466                      Pfizer/BioNTech      SWE
# Portugal                           70000                      Pfizer/BioNTech      PRT
# Greece                             55988                      Pfizer/BioNTech      GRC
# Austria                            52925                      Pfizer/BioNTech      AUT
# Netherlands                        45000                      Pfizer/BioNTech      NLD
# Ireland                            35000                      Pfizer/BioNTech      IRL
# Slovakia                           31785                      Pfizer/BioNTech      SVK
# Croatia                            30000                      Pfizer/BioNTech      HRV
# Lithuania                          27143                      Pfizer/BioNTech      LTU
# Slovenia                           24462                      Pfizer/BioNTech      SVN
# Norway                             21211                      Pfizer/BioNTech      NOR
# Oman                               20649                      Pfizer/BioNTech      OMN
# Czechia                            19918                      Pfizer/BioNTech      CZE
# Finland                            17617                      Pfizer/BioNTech      FIN
# Bulgaria                           15780                      Pfizer/BioNTech      BGR
# Estonia                            13481                      Pfizer/BioNTech      EST
# Chile                              10699                      Pfizer/BioNTech      CHL
# Latvia                              9899                      Pfizer/BioNTech      LVA
# Costa Rica                          9751                      Pfizer/BioNTech      CRI
# Serbia                              9300                      Pfizer/BioNTech      SRB
# Belgium                             8000                      Pfizer/BioNTech      BEL
# Cyprus                              6035                      Pfizer/BioNTech      CYP
# Iceland                             4875                      Pfizer/BioNTech      ISL
# Gibraltar                           2501                      Pfizer/BioNTech      GIB
# Kuwait                              2500                      Pfizer/BioNTech      KWT
# Luxembourg                          1943                      Pfizer/BioNTech      LUX
# Malta                               1400                      Pfizer/BioNTech      MLT
# Guinea                                25                            Sputnik V      GIN

# %%
plotLatestCountries.shape
# Out:
# (47, 3)

# %%
# Vaccine numbers
plotVaccine = plotLatestCountries.groupby('vaccine')['total_vaccinations'].sum()
plotVaccine.plot( kind = 'pie') 
plt.title("Vaccination per Vaccine - " + start_time.strftime('%Y %m %d'))
plt.suptitle("Total Vaccination: " + worldtotal_vaccinations_str ,y=1)
plt.savefig('images/Corona_VaccinationperVaccine.png')  
plt.show()

# %%
plotVaccine.sort_values(ascending=True)
# Out:
# vaccine
# Sputnik V                               907567
# Pfizer/BioNTech, Sinopharm             1373428
# Oxford/AstraZeneca, Pfizer/BioNTech    2843815
# Pfizer/BioNTech                        5653406
# CNBG, Sinovac                          9000000
# Moderna, Pfizer/BioNTech               9715631
# Name: total_vaccinations, dtype: int64

# %%
# Sweden have 10 000 doses....
#allCountries

# %%
end = datetime.now()
print("Ended: ", end) 
print('Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))
# Out:
# Ended:  2021-01-13 12:56:58.544587
# Time elapsed (hh:mm:ss.ms) 0:00:16.572123

# %% [markdown]
# ### Whole dataset
# see
# * [COVID-19 Data Processing Pipelines and datasets](https://github.com/covid19-data/covid19-data)

# %% [markdown]
# ### Compare population
# * using data from Wikidata

# %%
import sys,json
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"
 
# https://w.wiki/sp8
# see also https://www.wikidata.org/wiki/Wikidata:Project_chat#Brexit_in_Wikidata
queryWD = """SELECT DISTINCT ?cid  (SAMPLE(?continent) AS ?continent)  (SAMPLE(?memberEU) AS ?memberEU) ?country 
(REPLACE(STR(?cid), ".*Q", "Q") AS ?qid) ?population ?ISO3166_1 ?nominalGDPperCapita
# ?G20 ?IMF (sample(?genderH) AS ?genderH)
WHERE {
  # ?cid wdt:P31 wd:Q3624078;
    wdt:P1082 ?population.
  OPTIONAL { ?cid wdt:P298 ?ISO3166_1 }
  OPTIONAL { ?cid wdt:P2132 ?nominalGDPperCapita }
  # ?cid wdt:P6/wdt:P21 ?gHead # gender head of gov
  BIND (exists{?cid wdt:P463 wd:Q458} && not exists{?cid p:P463 [ ps:P463 wd:Q458 ; pq:P582 [] ]} AS ?memberEU)
  BIND (exists{?cid wdt:P463 wd:Q19771} && not exists{?cid p:P463 [ ps:P463 wd:Q19771 ; pq:P582 [] ]} AS ?G20)
  BIND (exists{?cid wdt:P463 wd:Q7804} && not exists{?cid p:P463 [ ps:P463 wd:Q7804 ; pq:P582 [] ]} AS ?IMF)
  {?cid wdt:P30 ?contid}
  OPTIONAL {
    # ?contid rdfs:label ?continent.
    FILTER((LANG(?continent)) = "en")
    # ?cid rdfs:label ?country.
    FILTER((LANG(?country)) = "en")
    # ?gHead rdfs:label ?genderH.
    FILTER((LANG(?genderH)) = "en")

  }
FILTER ( ?cid  not in ( wd:Q756617 ) ) #Danish Realm
}
GROUP BY ?population ?countryLabel ?country ?ISO3166_1 ?nominalGDPperCapita ?PPP_GDP_per_capita ?Human_Development_Index ?cid 
 # ?G20 ?IMF """


def get_sparql_dataframe(endpoint_url, query):
    """
    Helper function to convert SPARQL results into a Pandas data frame.
    """
    user_agent = "salgo60/%s.%s" % (sys.version_info[0], sys.version_info[1])
 
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query()

    processed_results = json.load(result.response)
    cols = processed_results['head']['vars']

    out = []
    for row in processed_results['results']['bindings']:
        item = []
        for c in cols:
            item.append(row.get(c, {}).get('value'))
        out.append(item)

    return pd.DataFrame(out, columns=cols)

WDpopulation = get_sparql_dataframe(endpoint_url, queryWD)
WDpopulation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   cid                  194 non-null    object
#  1   continent            194 non-null    object
#  2   memberEU             194 non-null    object
#  3   country              194 non-null    object
#  4   qid                  194 non-null    object
#  5   population           194 non-null    object
#  6   ISO3166_1            194 non-null    object
#  7   nominalGDPperCapita  191 non-null    object
#  8   G20                  194 non-null    object
#  9   IMF                  194 non-null    object
#  10  genderH              194 non-null    object
# dtypes: object(11)
# memory usage: 16.8+ KB

# %%
WDpopulation.sample(5)
# Out:
#                                       cid continent memberEU   country    qid population ISO3166_1 nominalGDPperCapita    G20    IMF genderH
# 122   http://www.wikidata.org/entity/Q214    Europe     true  Slovakia   Q214    5397036       SVK               17579  false  false    male
# 188  http://www.wikidata.org/entity/Q1049    Africa    false     Sudan  Q1049   40533330       SDN                2898  false  false    male
# 109    http://www.wikidata.org/entity/Q31    Europe     true   Belgium    Q31   11431406       BEL               43467  false  false    male
# 41    http://www.wikidata.org/entity/Q424      Asia    false  Cambodia   Q424   16005373       KHM                1384  false  false    male
# 27    http://www.wikidata.org/entity/Q826      Asia    false  Maldives   Q826     436330       MDV               11151  false  false    male

# %%
plotLatestCountries
# Out:
#                       total_vaccinations                              vaccine iso_code
# location
# Argentina                         107542                            Sputnik V      ARG
# Austria                            52925                      Pfizer/BioNTech      AUT
# Bahrain                            97776           Pfizer/BioNTech, Sinopharm      BHR
# Belgium                             8000                      Pfizer/BioNTech      BEL
# Bulgaria                           15780                      Pfizer/BioNTech      BGR
# Canada                            388493             Moderna, Pfizer/BioNTech      CAN
# Chile                              10699                      Pfizer/BioNTech      CHL
# China                            9000000                        CNBG, Sinovac      CHN
# Costa Rica                          9751                      Pfizer/BioNTech      CRI
# Croatia                            30000                      Pfizer/BioNTech      HRV
# Cyprus                              6035                      Pfizer/BioNTech      CYP
# Czechia                            19918                      Pfizer/BioNTech      CZE
# Denmark                           117104                      Pfizer/BioNTech      DNK
# Estonia                            13481                      Pfizer/BioNTech      EST
# Finland                            17617                      Pfizer/BioNTech      FIN
# France                            189834                      Pfizer/BioNTech      FRA
# Germany                           688782                      Pfizer/BioNTech      DEU
# Gibraltar                           2501                      Pfizer/BioNTech      GIB
# Greece                             55988                      Pfizer/BioNTech      GRC
# Guinea                                25                            Sputnik V      GIN
# Hungary                            86929                      Pfizer/BioNTech      HUN
# Iceland                             4875                      Pfizer/BioNTech      ISL
# Ireland                            35000                      Pfizer/BioNTech      IRL
# Israel                           1933294                      Pfizer/BioNTech      ISR
# Italy                             800730                      Pfizer/BioNTech      ITA
# Kuwait                              2500                      Pfizer/BioNTech      KWT
# Latvia                              9899                      Pfizer/BioNTech      LVA
# Lithuania                          27143                      Pfizer/BioNTech      LTU
# Luxembourg                          1943                      Pfizer/BioNTech      LUX
# Malta                               1400                      Pfizer/BioNTech      MLT
# Mexico                             92879                      Pfizer/BioNTech      MEX
# Netherlands                        45000                      Pfizer/BioNTech      NLD
# Norway                             21211                      Pfizer/BioNTech      NOR
# Oman                               20649                      Pfizer/BioNTech      OMN
# Poland                            309620                      Pfizer/BioNTech      POL
# Portugal                           70000                      Pfizer/BioNTech      PRT
# Romania                           140447                      Pfizer/BioNTech      ROU
# Russia                            800000                            Sputnik V      RUS
# Saudi Arabia                      178337                      Pfizer/BioNTech      SAU
# Serbia                              9300                      Pfizer/BioNTech      SRB
# Slovakia                           31785                      Pfizer/BioNTech      SVK
# Slovenia                           24462                      Pfizer/BioNTech      SVN
# Spain                             488122                      Pfizer/BioNTech      ESP
# Sweden                             79466                      Pfizer/BioNTech      SWE
# United Arab Emirates             1275652           Pfizer/BioNTech, Sinopharm      ARE
# United Kingdom                   2843815  Oxford/AstraZeneca, Pfizer/BioNTech      GBR
# United States                    9327138             Moderna, Pfizer/BioNTech      USA

# %%
#plotCountriesPopulation = pd.merge(plotLatestCountries, reconciliationCountries,how='outer', left_index=True, right_index=True,indicator=True)   
CountriesData = pd.merge(plotLatestCountries, WDpopulation,how='inner', left_on="iso_code", right_on="ISO3166_1" ,indicator=True)   
CountriesData
# Out:
#     total_vaccinations                              vaccine iso_code                                    cid  ...    G20    IMF genderH _merge
# 0               107542                            Sputnik V      ARG    http://www.wikidata.org/entity/Q414  ...   true  false    male   both
# 1                52925                      Pfizer/BioNTech      AUT     http://www.wikidata.org/entity/Q40  ...  false  false    male   both
# 2                97776           Pfizer/BioNTech, Sinopharm      BHR    http://www.wikidata.org/entity/Q398  ...  false  false    male   both
# 3                 8000                      Pfizer/BioNTech      BEL     http://www.wikidata.org/entity/Q31  ...  false  false    male   both
# 4                15780                      Pfizer/BioNTech      BGR    http://www.wikidata.org/entity/Q219  ...  false  false    male   both
# 5               388493             Moderna, Pfizer/BioNTech      CAN     http://www.wikidata.org/entity/Q16  ...   true  false    male   both
# 6                10699                      Pfizer/BioNTech      CHL    http://www.wikidata.org/entity/Q298  ...  false  false    male   both
# 7              9000000                        CNBG, Sinovac      CHN    http://www.wikidata.org/entity/Q148  ...   true  false    male   both
# 8                 9751                      Pfizer/BioNTech      CRI    http://www.wikidata.org/entity/Q800  ...  false  false    male   both
# 9                30000                      Pfizer/BioNTech      HRV    http://www.wikidata.org/entity/Q224  ...  false  false    male   both
# 10                6035                      Pfizer/BioNTech      CYP    http://www.wikidata.org/entity/Q229  ...  false  false    male   both
# 11               19918                      Pfizer/BioNTech      CZE    http://www.wikidata.org/entity/Q213  ...  false  false    male   both
# 12              117104                      Pfizer/BioNTech      DNK     http://www.wikidata.org/entity/Q35  ...  false  false  female   both
# 13               13481                      Pfizer/BioNTech      EST    http://www.wikidata.org/entity/Q191  ...  false  false    male   both
# 14               17617                      Pfizer/BioNTech      FIN     http://www.wikidata.org/entity/Q33  ...  false  false  female   both
# 15              189834                      Pfizer/BioNTech      FRA    http://www.wikidata.org/entity/Q142  ...   true  false    male   both
# 16              688782                      Pfizer/BioNTech      DEU    http://www.wikidata.org/entity/Q183  ...   true   true  female   both
# 17               55988                      Pfizer/BioNTech      GRC     http://www.wikidata.org/entity/Q41  ...  false  false    male   both
# 18                  25                            Sputnik V      GIN   http://www.wikidata.org/entity/Q1006  ...  false  false    male   both
# 19               86929                      Pfizer/BioNTech      HUN     http://www.wikidata.org/entity/Q28  ...  false  false    male   both
# 20                4875                      Pfizer/BioNTech      ISL    http://www.wikidata.org/entity/Q189  ...  false  false  female   both
# 21               35000                      Pfizer/BioNTech      IRL     http://www.wikidata.org/entity/Q27  ...  false  false    male   both
# 22             1933294                      Pfizer/BioNTech      ISR    http://www.wikidata.org/entity/Q801  ...  false  false    male   both
# 23              800730                      Pfizer/BioNTech      ITA     http://www.wikidata.org/entity/Q38  ...   true   true    male   both
# 24                2500                      Pfizer/BioNTech      KWT    http://www.wikidata.org/entity/Q817  ...  false  false    male   both
# 25                9899                      Pfizer/BioNTech      LVA    http://www.wikidata.org/entity/Q211  ...  false  false    male   both
# 26               27143                      Pfizer/BioNTech      LTU     http://www.wikidata.org/entity/Q37  ...  false  false  female   both
# 27                1943                      Pfizer/BioNTech      LUX     http://www.wikidata.org/entity/Q32  ...  false  false    male   both
# 28                1400                      Pfizer/BioNTech      MLT    http://www.wikidata.org/entity/Q233  ...  false  false    male   both
# 29               92879                      Pfizer/BioNTech      MEX     http://www.wikidata.org/entity/Q96  ...   true  false    male   both
# 30               45000                      Pfizer/BioNTech      NLD  http://www.wikidata.org/entity/Q29999  ...  false  false    male   both
# 31               21211                      Pfizer/BioNTech      NOR     http://www.wikidata.org/entity/Q20  ...  false  false  female   both
# 32               20649                      Pfizer/BioNTech      OMN    http://www.wikidata.org/entity/Q842  ...  false  false    male   both
# 33              309620                      Pfizer/BioNTech      POL     http://www.wikidata.org/entity/Q36  ...  false   true    male   both
# 34               70000                      Pfizer/BioNTech      PRT     http://www.wikidata.org/entity/Q45  ...  false  false    male   both
# 35              140447                      Pfizer/BioNTech      ROU    http://www.wikidata.org/entity/Q218  ...  false  false    male   both
# 36              800000                            Sputnik V      RUS    http://www.wikidata.org/entity/Q159  ...   true  false    male   both
# 37              178337                      Pfizer/BioNTech      SAU    http://www.wikidata.org/entity/Q851  ...   true  false    male   both
# 38                9300                      Pfizer/BioNTech      SRB    http://www.wikidata.org/entity/Q403  ...  false  false  female   both
# 39               31785                      Pfizer/BioNTech      SVK    http://www.wikidata.org/entity/Q214  ...  false  false    male   both
# 40               24462                      Pfizer/BioNTech      SVN    http://www.wikidata.org/entity/Q215  ...  false  false    male   both
# 41              488122                      Pfizer/BioNTech      ESP     http://www.wikidata.org/entity/Q29  ...  false  false    male   both
# 42               79466                      Pfizer/BioNTech      SWE     http://www.wikidata.org/entity/Q34  ...  false  false    male   both
# 43             1275652           Pfizer/BioNTech, Sinopharm      ARE    http://www.wikidata.org/entity/Q878  ...  false  false    male   both
# 44             2843815  Oxford/AstraZeneca, Pfizer/BioNTech      GBR    http://www.wikidata.org/entity/Q145  ...   true  false    male   both
# 45             9327138             Moderna, Pfizer/BioNTech      USA     http://www.wikidata.org/entity/Q30  ...   true  false    male   both
#
# [46 rows x 15 columns]

# %%
#del CountriesData['country']
#del CountriesData['qid']
#del CountriesData['_merge']

CountriesData['population'] = CountriesData['population'].astype(int)
CountriesData['nominalGDPperCapita'] = CountriesData['nominalGDPperCapita'].astype(float)
CountriesData["memberEU"].replace({"true": "1", "false": "0"}, inplace=True)
CountriesData['memberEU'] = CountriesData['memberEU'].astype(int)
# G20 IMF
CountriesData["G20"].replace({"true": "1", "false": "0"}, inplace=True)
CountriesData['G20'] = CountriesData['G20'].astype(int)
CountriesData["IMF"].replace({"true": "1", "false": "0"}, inplace=True)
CountriesData['IMF'] = CountriesData['IMF'].astype(int)
CountriesData['genderFlag'] = CountriesData['genderH']
CountriesData["genderFlag"].replace({"male": "1", "female": "0"}, inplace=True)
CountriesData['genderFlag'] = CountriesData['genderFlag'].astype(int)

#"Correct United States of America
CountriesData["continent"].replace({"Oceania": "North America"}, inplace=True)
CountriesData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46 entries, 0 to 45
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   total_vaccinations   46 non-null     int64
#  1   vaccine              46 non-null     object
#  2   iso_code             46 non-null     object
#  3   cid                  46 non-null     object
#  4   continent            46 non-null     object
#  5   memberEU             46 non-null     int64
#  6   country              46 non-null     object
#  7   qid                  46 non-null     object
#  8   population           46 non-null     int64
#  9   ISO3166_1            46 non-null     object
#  10  nominalGDPperCapita  45 non-null     float64
#  11  G20                  46 non-null     int64
#  12  IMF                  46 non-null     int64
#  13  genderH              46 non-null     object
#  14  _merge               46 non-null     category
#  15  genderFlag           46 non-null     int64
# dtypes: category(1), float64(1), int64(6), object(8)
# memory usage: 5.9+ KB

# %%
#CountriesData

# %%
CountriesData['Country'] = CountriesData.index

# %%
CountriesData["vaccinations_population_percent"] = CountriesData["total_vaccinations"]/CountriesData["population"] * 100

correlations = CountriesData.corr()  
correlations["total_vaccinations"]
# Out:
# total_vaccinations                 1.000000
# memberEU                          -0.325085
# population                         0.799960
# nominalGDPperCapita                0.072891
# G20                                0.467369
# IMF                               -0.005776
# genderFlag                         0.115118
# Country                            0.144842
# vaccinations_population_percent    0.192478
# Name: total_vaccinations, dtype: float64

# %%
correlations["vaccinations_population_percent"]
# Out:
# total_vaccinations                 0.192478
# memberEU                          -0.293096
# population                        -0.038519
# nominalGDPperCapita                0.143680
# G20                               -0.065913
# IMF                               -0.042811
# genderFlag                         0.083412
# Country                            0.129903
# vaccinations_population_percent    1.000000
# Name: vaccinations_population_percent, dtype: float64

# %%
# see https://medium.com/@szabo.bibor/how-to-create-a-seaborn-correlation-heatmap-in-python-834c0686b88e
#plt.rcParams['figure.figsize'] = (8.0, 8.0)
#heatmap = sns.heatmap(correlations, vmin=-1, vmax=1, annot=True)
#heatmap.set_title('Corona vaccinations Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %%
import numpy as np
plt.figure(figsize=(10, 3))
#np.triu(np.ones_like(correlations["total_vaccinations","vaccinations_population_percent"]))
#mask = np.triu(np.ones_like(correlations, dtype=np.bool))
heatmap = sns.heatmap(correlations[{"total_vaccinations","vaccinations_population_percent"}],vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Triangle Correlation Heatmap - Corona vaccination progress', fontdict={'fontsize':10},y=0.9, pad=16);
plt.suptitle(start_time.strftime('%Y %m %d - %-H:%M'), fontsize=10,color = 'gray',x=0.9)
plt.savefig('images/Correlation_heatmap.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
CountriesData = CountriesData.sort_values(by=['vaccinations_population_percent'],ascending=False)
CountriesData[{"total_vaccinations","population","vaccinations_population_percent","continent",
               "memberEU","G20","IMF","country"}]
# Out:
#     memberEU                     country  vaccinations_population_percent  population  IMF  G20      continent  total_vaccinations
# 22         0                      Israel                        21.261344     9093000    0    0           Asia             1933294
# 43         0        United Arab Emirates                        13.570557     9400145    0    0           Asia             1275652
# 2          0                     Bahrain                         6.550787     1492584    0    0           Asia               97776
# 44         0              United Kingdom                         4.307357    66022273    0    1         Europe             2843815
# 45         0    United States of America                         2.841565   328239523    0    1  North America             9327138
# 12         1                     Denmark                         2.009519     5827463    0    0         Europe              117104
# 20         0                     Iceland                         1.365355      357050    0    0         Europe                4875
# 23         1                       Italy                         1.327536    60317000    1    1         Europe              800730
# 40         1                    Slovenia                         1.183523     2066880    0    0         Europe               24462
# 41         1                       Spain                         1.044490    46733038    0    0         Europe              488122
# 5          0                      Canada                         1.025188    37894799    0    1  North America              388493
# 13         1                     Estonia                         1.017572     1324820    0    0         Europe               13481
# 26         1                   Lithuania                         0.972574     2790842    0    0         Europe               27143
# 19         1                     Hungary                         0.889798     9769526    0    0         Europe               86929
# 16         1                     Germany                         0.828368    83149300    1    1         Europe              688782
# 33         1                      Poland                         0.806668    38382576    1    0         Europe              309620
# 42         1                      Sweden                         0.766068    10373225    0    0         Europe               79466
# 21         1                     Ireland                         0.735006     4761865    0    0         Europe               35000
# 9          1                     Croatia                         0.730728     4105493    0    0         Europe               30000
# 35         1                     Romania                         0.717059    19586539    0    0         Europe              140447
# 34         1                    Portugal                         0.660377    10600000    0    0         Europe               70000
# 7          0  People's Republic of China                         0.638516  1409517397    0    1           Asia             9000000
# 1          1                     Austria                         0.600792     8809212    0    0         Europe               52925
# 39         1                    Slovakia                         0.588934     5397036    0    0         Europe               31785
# 36         0                      Russia                         0.544943   146804372    0    1         Europe              800000
# 37         0                Saudi Arabia                         0.540415    33000000    0    1           Asia              178337
# 10         1                      Cyprus                         0.528845     1141166    0    0         Europe                6035
# 17         1                      Greece                         0.520314    10760421    0    0         Europe               55988
# 25         1                      Latvia                         0.518544     1909000    0    0         Europe                9899
# 32         0                        Oman                         0.427562     4829480    0    0           Asia               20649
# 31         0                      Norway                         0.395169     5367580    0    0         Europe               21211
# 14         1                     Finland                         0.320248     5501043    0    0         Europe               17617
# 27         1                  Luxembourg                         0.310330      626108    0    0         Europe                1943
# 28         1                       Malta                         0.300886      465292    0    0         Europe                1400
# 15         1                      France                         0.284916    66628000    0    1         Europe              189834
# 30         1  Kingdom of the Netherlands                         0.263147    17100715    0    0         Europe               45000
# 0          0                   Argentina                         0.239308    44938712    0    1  South America              107542
# 4          1                    Bulgaria                         0.225427     7000039    0    0         Europe               15780
# 8          0                  Costa Rica                         0.198766     4905769    0    0  North America                9751
# 11         1              Czech Republic                         0.186255    10693939    0    0         Europe               19918
# 38         0                      Serbia                         0.132436     7022268    0    0         Europe                9300
# 29         0                      Mexico                         0.071157   130526945    0    1  North America               92879
# 3          1                     Belgium                         0.069983    11431406    0    0         Europe                8000
# 6          0                       Chile                         0.059259    18054726    0    0  South America               10699
# 24         0                      Kuwait                         0.054348     4600000    0    0           Asia                2500
# 18         0                      Guinea                         0.000197    12717176    0    0         Africa                  25

# %% [markdown]
# ## Vaccination numbers % of population

# %%
plt.rcParams['figure.figsize'] = (15.0, 10.0)
sns.set(style="whitegrid", palette="rainbow") 
sns.barplot( x = "ISO3166_1",y = "vaccinations_population_percent", data=CountriesData). \
            set_title("Vaccination numbers % of population", \
                      fontsize=30)
plt.ylabel("percent of population",fontsize=20)
plt.xlabel("Country",fontsize=30)
plt.suptitle(start_time.strftime('%Y %m %d - %-H:%M - World total ' + worldtotal_vaccinations_str), fontsize=15,color = 'gray')
plt.savefig("images/Corona_VaccinationperCountryPopulation_sns_2.png",bbox_inches="tight")
plt.show()

# %%
#Top 10 
plt.rcParams['figure.figsize'] = (15.0, 10.0)
sns.set(style="whitegrid", palette="rainbow") 
sns.barplot( x = "ISO3166_1",y = "vaccinations_population_percent", data=CountriesData[0:11]). \
            set_title("Vaccination numbers % of population - top 10", \
                      fontsize=30)
plt.ylabel("percent of population",fontsize=20)
plt.xlabel("Top 10 Countries",fontsize=30)
plt.suptitle(start_time.strftime('%Y %m %d - %-H:%M - World total ' + worldtotal_vaccinations_str ), fontsize=15,color = 'gray')

plt.savefig("images/Corona_VaccinationperCountryPopulation_sns_1_10.png",bbox_inches="tight")
plt.show()

# %%
# 10-
plt.rcParams['figure.figsize'] = (15.0, 10.0)
sns.set(style="whitegrid", palette="rainbow") 
sns.barplot( x = "ISO3166_1",y = "vaccinations_population_percent", data=CountriesData[11:]). \
            set_title("Vaccination numbers % of population - 10 + ", \
                      fontsize=30)
plt.ylabel("percent of population",fontsize=20)
plt.xlabel("Countries",fontsize=30)
plt.suptitle(start_time.strftime('%Y %m %d - %-H:%M - World total ' + worldtotal_vaccinations_str ), fontsize=15,color = 'gray')
plt.savefig("images/Corona_VaccinationperCountryPopulation_sns_10_.png",bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Scatter plots

# %%
#https://seaborn.pydata.org/tutorial/categorical.html
plt.rcParams.update(plt.rcParamsDefault) 
plt.rcParams['figure.figsize'] = (15.0, 10.0)
sns.color_palette("magma")
sns.catplot(x="continent", y="vaccinations_population_percent", data=CountriesData,kind="swarm",legend='brief')
plt.title("% of population / continent scatter plot " , fontsize=15, y=0.9 )
plt.ylabel("percent of population",fontsize=10)
plt.xlabel("Continent",fontsize=10)
plt.suptitle(start_time.strftime('%Y %m %d - %-H:%M - World total ' + worldtotal_vaccinations_str ), x=1.7,y=1.04, fontsize=10,color = 'gray')

plt.savefig("images/Corona_VaccinationperCountryPopulation_Categorical_scatterplot.png",bbox_inches="tight")
plt.show()

# %%
plt.rcParams.update(plt.rcParamsDefault) 
plt.rcParams['figure.figsize'] = (15.0, 10.0)
sns.color_palette("magma")
sns.catplot(x="continent", y="total_vaccinations", data=CountriesData,kind="swarm",legend='brief')
plt.title("Total vaccinations / Continent scatter plot (million)" , fontsize=15, x=1,y=1.1 )
plt.ylabel("Total vaccinations million",fontsize=10)
plt.xlabel("Continent",fontsize=10)
plt.suptitle(start_time.strftime('%Y %m %d - %-H:%M - World total ' + worldtotal_vaccinations_str ), x=1.7,y=1.04, fontsize=10,color = 'gray')

plt.savefig("images/Corona_VaccinationperCountryTotal_Categorical_scatterplot.png",bbox_inches="tight")
plt.show()

# %%
CountriesData["Member EU"] = CountriesData["memberEU"]
CountriesData["Member EU"] = CountriesData["Member EU"].astype(str)
CountriesData["Member EU"].replace({"1": "Member in EU", "0": "non Member"}, inplace=True)

#CountriesData

# %%
plt.rcParams.update(plt.rcParamsDefault) 
plt.rcParams['figure.figsize'] = (15.0, 10.0)
sns.color_palette("magma")
sns.catplot(x="Member EU", y="vaccinations_population_percent", data=CountriesData,kind="swarm",legend='brief')
plt.title("% EU member scatter plot " , fontsize=15, y=0.9 )
plt.ylabel("percent of population",fontsize=10)
plt.xlabel("Member of EU",fontsize=10)
plt.suptitle(start_time.strftime('%Y %m %d - %-H:%M - World total ' + worldtotal_vaccinations_str), x=1.7,y=1.04, fontsize=10,color = 'gray')

plt.savefig("images/Corona_VaccinationperCountryPopulation_EUCategorical_scatterplot.png",bbox_inches="tight")
plt.show()

# %%
CountriesData["Member G20"] = CountriesData["G20"]
CountriesData["Member G20"] = CountriesData["G20"].astype(str)
CountriesData["Member G20"].replace({"1": "Member G20", "0": "non Member"}, inplace=True)
plt.rcParams.update(plt.rcParamsDefault) 
plt.rcParams['figure.figsize'] = (15.0, 10.0)
sns.color_palette("magma")
sns.catplot(x="Member G20", y="vaccinations_population_percent", data=CountriesData,kind="swarm",legend='brief')
plt.title("% G20 member scatter plot " , fontsize=15, y=0.9 )
plt.ylabel("percent of population",fontsize=10)
plt.xlabel("Member of G20",fontsize=10)
plt.suptitle(start_time.strftime('%Y %m %d - %-H:%M - World total '  + worldtotal_vaccinations_str), x=1.7,y=1.04, fontsize=10,color = 'gray')

plt.savefig("images/Corona_VaccinationperCountryPopulation_G20_Categorical_scatterplot.png",bbox_inches="tight")
plt.show()

# %%
CountriesData["Member IMF"] = CountriesData["IMF"]
CountriesData["Member IMF"] = CountriesData["IMF"].astype(str)
CountriesData["Member IMF"].replace({"1": "Member IMF", "0": "non Member"}, inplace=True)
plt.rcParams.update(plt.rcParamsDefault) 
plt.rcParams['figure.figsize'] = (15.0, 10.0)
sns.color_palette("magma")
sns.catplot(x="Member IMF", y="vaccinations_population_percent", data=CountriesData,kind="swarm",legend='brief')
plt.title("% IMF member scatter plot " , fontsize=15, y=0.9 )
plt.ylabel("percent of population",fontsize=10)
plt.xlabel("Member of IMF",fontsize=10)
plt.suptitle(start_time.strftime('%Y %m %d - %-H:%M - World total ' + worldtotal_vaccinations_str), x=1.7,y=1.04, fontsize=10,color = 'gray')

plt.savefig("images/Corona_VaccinationperCountryPopulation_IMF_Categorical_scatterplot.png",bbox_inches="tight")
plt.show()

# %%
CountriesDataEurope = CountriesData[CountriesData["continent"] == "Europe"]
europetotal_vaccinations_str = europetotal_vaccinations_str = '{:,}'.format(CountriesDataEurope.sum()["total_vaccinations"]).replace(',', ' ')
print(worldtotal_vaccinations_str, plotLatestCountries.shape,europetotal_vaccinations_str)
# Out:
# 29 493 847 (47, 3) 7 046 611

# %%
plt.rcParams['figure.figsize'] = (15.0, 10.0)
sns.set(style="whitegrid", palette="rainbow") 
sns.barplot( x = "ISO3166_1",y = "vaccinations_population_percent", data=CountriesDataEurope). \
            set_title("Europe: Vaccination numbers % of population ", \
                      fontsize=30)
plt.ylabel("percent of population",fontsize=20)
plt.xlabel("Countries in Europe",fontsize=20)
plt.suptitle(start_time.strftime('%Y %m %d - %-H:%M - Total: World ' + worldtotal_vaccinations_str) + 
             " - Europe " + europetotal_vaccinations_str 
             ,fontsize=15,color = 'gray')
plt.savefig("images/Corona_EuropeVaccinationperCountryPopulation.png",bbox_inches="tight")
plt.show()

# %%
#CountriesDataEurope

# %%
CountriesDataEurope = CountriesDataEurope.sort_values(by=['iso_code'],ascending=True)
plt.rcParams['figure.figsize'] = (15.0, 10.0)
sns.set(style="whitegrid", palette="rainbow") 
sns.barplot( x = "ISO3166_1",y = "total_vaccinations", data=CountriesDataEurope). \
            set_title("Europe: total Vaccination per country ", \
                      fontsize=30)
plt.ylabel("Vaccination",fontsize=20)
plt.xlabel("Countries in Europe",fontsize=20)
plt.suptitle(start_time.strftime('%Y %m %d - %-H:%M - Total: World ' + worldtotal_vaccinations_str) + 
             " - Europe " + europetotal_vaccinations_str 
             ,fontsize=15,color = 'gray')
plt.savefig("images/Corona_EuropeVaccinationperCountry.png",bbox_inches="tight")
plt.show()

# %%
#All countries Europe also no reporting
WDpopulationEurope = WDpopulation[WDpopulation["continent"] == "Europe"]
 
#CountriesDataEuropeAll = CountriesDataEurope
CountriesDataEuropeAll = pd.merge(WDpopulationEurope,CountriesDataEurope,how='outer',on="ISO3166_1")  
CountriesDataEuropeAll = pd.merge(WDpopulationEurope,CountriesDataEurope,how='outer',on="ISO3166_1") \
        [{"memberEU_x","country_x","ISO3166_1","total_vaccinations","vaccinations_population_percent","genderH_x"}]

CountriesDataEuropeAll['total_vaccinations'] = CountriesDataEuropeAll['total_vaccinations'].fillna(0)
CountriesDataEuropeAll['vaccinations_population_percent'] = CountriesDataEuropeAll['vaccinations_population_percent'].fillna(0)
CountriesDataEuropeAll = CountriesDataEuropeAll.sort_values(by=['ISO3166_1'],ascending=True)
#CountriesDataEuropeAll["Member EU"] = CountriesDataEuropeAll["Member EU"].fillna("non Member")
CountriesDataEuropeAll["memberEU_x"].replace({"true": "Member in EU", "false": "non Member"}, inplace=True)
CountriesDataEuropeAll["memberEU_x"].replace({"true": "Member in EU", "false": "non Member"}, inplace=True)
CountriesDataEuropeAll.rename(columns = {'memberEU_x': 'memberEU'}, inplace = True)
CountriesDataEuropeAll.rename(columns = {'genderH_x': 'head_gender'}, inplace = True)
# name change 
CountriesDataEuropeAll
#CountriesDataEurope
#WDpopulationEurope 
#CountriesDataEurope
# Out:
#         memberEU  vaccinations_population_percent ISO3166_1                   country_x head_gender  total_vaccinations
# 36    non Member                         0.000000       ALB                     Albania        male                 0.0
# 10    non Member                         0.000000       AND                     Andorra        male                 0.0
# 25    non Member                         0.000000       ARM                     Armenia        male                 0.0
# 8   Member in EU                         0.600792       AUT                     Austria        male             52925.0
# 29    non Member                         0.000000       AZE                  Azerbaijan        male                 0.0
# 24  Member in EU                         0.069983       BEL                     Belgium        male              8000.0
# 22  Member in EU                         0.225427       BGR                    Bulgaria        male             15780.0
# 32    non Member                         0.000000       BIH      Bosnia and Herzegovina        male                 0.0
# 39    non Member                         0.000000       BLR                     Belarus        male                 0.0
# 3     non Member                         0.000000       CHE                 Switzerland        male                 0.0
# 37  Member in EU                         0.528845       CYP                      Cyprus        male              6035.0
# 42  Member in EU                         0.186255       CZE              Czech Republic        male             19918.0
# 31  Member in EU                         0.828368       DEU                     Germany      female            688782.0
# 14  Member in EU                         2.009519       DNK                     Denmark      female            117104.0
# 0   Member in EU                         1.044490       ESP                       Spain        male            488122.0
# 44  Member in EU                         1.017572       EST                     Estonia        male             13481.0
# 9   Member in EU                         0.320248       FIN                     Finland      female             17617.0
# 34  Member in EU                         0.284916       FRA                      France        male            189834.0
# 13    non Member                         4.307357       GBR              United Kingdom        male           2843815.0
# 17    non Member                         0.000000       GEO                     Georgia        male                 0.0
# 30  Member in EU                         0.520314       GRC                      Greece        male             55988.0
# 15  Member in EU                         0.730728       HRV                     Croatia        male             30000.0
# 19  Member in EU                         0.889798       HUN                     Hungary        male             86929.0
# 11  Member in EU                         0.735006       IRL                     Ireland        male             35000.0
# 18    non Member                         1.365355       ISL                     Iceland      female              4875.0
# 46  Member in EU                         1.327536       ITA                       Italy        male            800730.0
# 5     non Member                         0.000000       KAZ                  Kazakhstan        male                 0.0
# 7     non Member                         0.000000       LIE               Liechtenstein        male                 0.0
# 35  Member in EU                         0.972574       LTU                   Lithuania      female             27143.0
# 6   Member in EU                         0.310330       LUX                  Luxembourg        male              1943.0
# 38  Member in EU                         0.518544       LVA                      Latvia        male              9899.0
# 43    non Member                         0.000000       MCO                      Monaco        male                 0.0
# 20    non Member                         0.000000       MDA                     Moldova        male                 0.0
# 45    non Member                         0.000000       MKD             North Macedonia        male                 0.0
# 27  Member in EU                         0.300886       MLT                       Malta        male              1400.0
# 21    non Member                         0.000000       MNE                  Montenegro        male                 0.0
# 1   Member in EU                         0.263147       NLD  Kingdom of the Netherlands        male             45000.0
# 40    non Member                         0.395169       NOR                      Norway      female             21211.0
# 47  Member in EU                         0.806668       POL                      Poland        male            309620.0
# 49  Member in EU                         0.660377       PRT                    Portugal        male             70000.0
# 4   Member in EU                         0.717059       ROU                     Romania        male            140447.0
# 26    non Member                         0.544943       RUS                      Russia        male            800000.0
# 16    non Member                         0.000000       SMR                  San Marino      female                 0.0
# 2     non Member                         0.132436       SRB                      Serbia      female              9300.0
# 28  Member in EU                         0.588934       SVK                    Slovakia        male             31785.0
# 33  Member in EU                         1.183523       SVN                    Slovenia        male             24462.0
# 41  Member in EU                         0.766068       SWE                      Sweden        male             79466.0
# 48    non Member                         0.000000       TUR                      Turkey        male                 0.0
# 23    non Member                         0.000000       UKR                     Ukraine        male                 0.0
# 12    non Member                         0.000000       VAT                Vatican City        male                 0.0

# %% [markdown]
# ## All countries on continent Europe

# %%
plt.rcParams['figure.figsize'] = (20.0, 10.0)
sns.set(style="whitegrid", palette="rainbow") 
sns.barplot( x = "ISO3166_1",y = "total_vaccinations", data=CountriesDataEuropeAll). \
            set_title("Europe: total Vaccination - all countries ", \
                      fontsize=30)
plt.ylabel("Vaccination",fontsize=20)
plt.xlabel("All countries on continent Europe",fontsize=20)
plt.suptitle(start_time.strftime('%Y %m %d - %-H:%M - Total: World ' + worldtotal_vaccinations_str) + 
             " - Europe " + europetotal_vaccinations_str 
             ,fontsize=15,color = 'gray')

plt.savefig("images/Corona_EuropeAllVaccinationperCountry.png",bbox_inches="tight")
plt.show()

# %%
CountriesDataEuropeAll.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 36 to 12
# Data columns (total 6 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   memberEU                         50 non-null     object
#  1   vaccinations_population_percent  50 non-null     float64
#  2   ISO3166_1                        50 non-null     object
#  3   country_x                        50 non-null     object
#  4   head_gender                      50 non-null     object
#  5   total_vaccinations               50 non-null     float64
# dtypes: float64(2), object(4)
# memory usage: 5.2+ KB

# %%
CountriesDataEuropeAll
# Out:
#         memberEU  vaccinations_population_percent ISO3166_1                   country_x head_gender  total_vaccinations
# 36    non Member                         0.000000       ALB                     Albania        male                 0.0
# 10    non Member                         0.000000       AND                     Andorra        male                 0.0
# 25    non Member                         0.000000       ARM                     Armenia        male                 0.0
# 8   Member in EU                         0.600792       AUT                     Austria        male             52925.0
# 29    non Member                         0.000000       AZE                  Azerbaijan        male                 0.0
# 24  Member in EU                         0.069983       BEL                     Belgium        male              8000.0
# 22  Member in EU                         0.225427       BGR                    Bulgaria        male             15780.0
# 32    non Member                         0.000000       BIH      Bosnia and Herzegovina        male                 0.0
# 39    non Member                         0.000000       BLR                     Belarus        male                 0.0
# 3     non Member                         0.000000       CHE                 Switzerland        male                 0.0
# 37  Member in EU                         0.528845       CYP                      Cyprus        male              6035.0
# 42  Member in EU                         0.186255       CZE              Czech Republic        male             19918.0
# 31  Member in EU                         0.828368       DEU                     Germany      female            688782.0
# 14  Member in EU                         2.009519       DNK                     Denmark      female            117104.0
# 0   Member in EU                         1.044490       ESP                       Spain        male            488122.0
# 44  Member in EU                         1.017572       EST                     Estonia        male             13481.0
# 9   Member in EU                         0.320248       FIN                     Finland      female             17617.0
# 34  Member in EU                         0.284916       FRA                      France        male            189834.0
# 13    non Member                         4.307357       GBR              United Kingdom        male           2843815.0
# 17    non Member                         0.000000       GEO                     Georgia        male                 0.0
# 30  Member in EU                         0.520314       GRC                      Greece        male             55988.0
# 15  Member in EU                         0.730728       HRV                     Croatia        male             30000.0
# 19  Member in EU                         0.889798       HUN                     Hungary        male             86929.0
# 11  Member in EU                         0.735006       IRL                     Ireland        male             35000.0
# 18    non Member                         1.365355       ISL                     Iceland      female              4875.0
# 46  Member in EU                         1.327536       ITA                       Italy        male            800730.0
# 5     non Member                         0.000000       KAZ                  Kazakhstan        male                 0.0
# 7     non Member                         0.000000       LIE               Liechtenstein        male                 0.0
# 35  Member in EU                         0.972574       LTU                   Lithuania      female             27143.0
# 6   Member in EU                         0.310330       LUX                  Luxembourg        male              1943.0
# 38  Member in EU                         0.518544       LVA                      Latvia        male              9899.0
# 43    non Member                         0.000000       MCO                      Monaco        male                 0.0
# 20    non Member                         0.000000       MDA                     Moldova        male                 0.0
# 45    non Member                         0.000000       MKD             North Macedonia        male                 0.0
# 27  Member in EU                         0.300886       MLT                       Malta        male              1400.0
# 21    non Member                         0.000000       MNE                  Montenegro        male                 0.0
# 1   Member in EU                         0.263147       NLD  Kingdom of the Netherlands        male             45000.0
# 40    non Member                         0.395169       NOR                      Norway      female             21211.0
# 47  Member in EU                         0.806668       POL                      Poland        male            309620.0
# 49  Member in EU                         0.660377       PRT                    Portugal        male             70000.0
# 4   Member in EU                         0.717059       ROU                     Romania        male            140447.0
# 26    non Member                         0.544943       RUS                      Russia        male            800000.0
# 16    non Member                         0.000000       SMR                  San Marino      female                 0.0
# 2     non Member                         0.132436       SRB                      Serbia      female              9300.0
# 28  Member in EU                         0.588934       SVK                    Slovakia        male             31785.0
# 33  Member in EU                         1.183523       SVN                    Slovenia        male             24462.0
# 41  Member in EU                         0.766068       SWE                      Sweden        male             79466.0
# 48    non Member                         0.000000       TUR                      Turkey        male                 0.0
# 23    non Member                         0.000000       UKR                     Ukraine        male                 0.0
# 12    non Member                         0.000000       VAT                Vatican City        male                 0.0

# %% [markdown]
# ### Countries in EU

# %%
#CountriesDataEuropeEU[CountriesDataEuropeEU["ISO3166_1"] == "RUS"]
#CountriesDataEuropeEU
CountriesDataEuropeAll.rename(columns = {'country_x': 'country'}, inplace = True)
CountriesDataEuropeAll.rename(columns = {'ISO3166_1': 'ISO3166-1'}, inplace = True)

# %%
CountriesDataEuropeEU = CountriesDataEuropeAll[CountriesDataEuropeAll["memberEU"] == "Member in EU"]

plt.rcParams['figure.figsize'] = (20.0, 10.0)
sns.set(style="whitegrid", palette="rainbow") 
sns.barplot( x = "ISO3166-1",y = "total_vaccinations", data=CountriesDataEuropeEU). \
            set_title("Europe: total Vaccination - EU countries", \
                      fontsize=30)
plt.ylabel("Vaccination",fontsize=20)
plt.xlabel("All EU countries",fontsize=20)
plt.suptitle(start_time.strftime('%Y %m %d - %-H:%M - Total: World ' + worldtotal_vaccinations_str) + 
             " - Europe " + europetotal_vaccinations_str 
             ,fontsize=15,color = 'gray')
#plt.annotate('actual group', xy=(x+0.2,y), xytext=(x+0.3, 300),
#             arrowprops=dict(facecolor='black', shrink=0.05, headwidth=20, width=7))
#for p in ax.patches:
#    print(p)

plt.savefig("images/EU_VaccinationperCountry.png",bbox_inches="tight")
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20.0, 10.0)

sns.set(style="whitegrid", palette="rainbow") 
sns.barplot( x = "ISO3166-1",y = "vaccinations_population_percent", data=CountriesDataEuropeEU). \
            set_title("Europe: Vaccination numbers % of population - EU countries", \
                      fontsize=30)
style = dict(size=10, color='gray')

plt.ylabel("Vaccination numbers % of population",fontsize=20)
plt.xlabel("All EU countries",fontsize=20)
plt.suptitle(start_time.strftime('%Y %m %d - %-H:%M - Total: World ' + worldtotal_vaccinations_str) + 
             " - Europe " + europetotal_vaccinations_str 
             ,fontsize=15,color = 'gray')

plt.savefig("images/EU_PercentVaccinationperCountry.png",bbox_inches="tight")
plt.show()

# %%
CountriesDataEuropeEU
#WDpopulationEuropeEU
# Out:
#         memberEU  vaccinations_population_percent ISO3166-1                     country head_gender  total_vaccinations
# 8   Member in EU                         0.600792       AUT                     Austria        male             52925.0
# 24  Member in EU                         0.069983       BEL                     Belgium        male              8000.0
# 22  Member in EU                         0.225427       BGR                    Bulgaria        male             15780.0
# 37  Member in EU                         0.528845       CYP                      Cyprus        male              6035.0
# 42  Member in EU                         0.186255       CZE              Czech Republic        male             19918.0
# 31  Member in EU                         0.828368       DEU                     Germany      female            688782.0
# 14  Member in EU                         2.009519       DNK                     Denmark      female            117104.0
# 0   Member in EU                         1.044490       ESP                       Spain        male            488122.0
# 44  Member in EU                         1.017572       EST                     Estonia        male             13481.0
# 9   Member in EU                         0.320248       FIN                     Finland      female             17617.0
# 34  Member in EU                         0.284916       FRA                      France        male            189834.0
# 30  Member in EU                         0.520314       GRC                      Greece        male             55988.0
# 15  Member in EU                         0.730728       HRV                     Croatia        male             30000.0
# 19  Member in EU                         0.889798       HUN                     Hungary        male             86929.0
# 11  Member in EU                         0.735006       IRL                     Ireland        male             35000.0
# 46  Member in EU                         1.327536       ITA                       Italy        male            800730.0
# 35  Member in EU                         0.972574       LTU                   Lithuania      female             27143.0
# 6   Member in EU                         0.310330       LUX                  Luxembourg        male              1943.0
# 38  Member in EU                         0.518544       LVA                      Latvia        male              9899.0
# 27  Member in EU                         0.300886       MLT                       Malta        male              1400.0
# 1   Member in EU                         0.263147       NLD  Kingdom of the Netherlands        male             45000.0
# 47  Member in EU                         0.806668       POL                      Poland        male            309620.0
# 49  Member in EU                         0.660377       PRT                    Portugal        male             70000.0
# 4   Member in EU                         0.717059       ROU                     Romania        male            140447.0
# 28  Member in EU                         0.588934       SVK                    Slovakia        male             31785.0
# 33  Member in EU                         1.183523       SVN                    Slovenia        male             24462.0
# 41  Member in EU                         0.766068       SWE                      Sweden        male             79466.0

# %% [markdown]
# ### Countries in EU not delivering Vaccination statistics

# %%
CountriesDataEuropeAll[(CountriesDataEuropeAll["memberEU"] == "Member in EU") & \
(CountriesDataEuropeAll["total_vaccinations"] == 0 )][{"total_vaccinations","country","ISO3166-1","memberEU"}]
# Out:
# Empty DataFrame
# Columns: [country, memberEU, total_vaccinations, ISO3166-1]
# Index: []

# %%
plt.rcParams.update(plt.rcParamsDefault) 
plt.rcParams['figure.figsize'] = (15.0, 10.0)
sns.color_palette("magma")
sns.catplot(x="memberEU", y="vaccinations_population_percent", data=CountriesDataEuropeAll,kind="swarm",legend='brief')
plt.title("% EU member scatter plot - all countries in Europe ",fontsize=10)
plt.ylabel("percent of population",fontsize=10)
plt.xlabel("Member of EU",fontsize=10)
plt.suptitle(start_time.strftime('%Y %m %d - %-H:%M - Total: World ' + worldtotal_vaccinations_str) + 
             " - Europe " + europetotal_vaccinations_str 
             ,fontsize=10,color = 'gray', y=1.1)

plt.savefig("images/Corona_VaccinationperPopulation_AllEurope_scatterplot.png",bbox_inches="tight")
plt.show()

# %%
#CountriesDataEuropeAll["head_gender"].astype('string')  
CountriesDataEuropeAll.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 36 to 12
# Data columns (total 6 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   memberEU                         50 non-null     object
#  1   vaccinations_population_percent  50 non-null     float64
#  2   ISO3166-1                        50 non-null     object
#  3   country                          50 non-null     object
#  4   head_gender                      50 non-null     object
#  5   total_vaccinations               50 non-null     float64
# dtypes: float64(2), object(4)
# memory usage: 5.2+ KB

# %%
#CountriesDataEuropeAll["vaccinations_population_percent].value_counts()

# %%
plt.rcParams.update(plt.rcParamsDefault) 
plt.rcParams['figure.figsize'] = (15.0, 10.0)
sns.color_palette("magma")
sns.catplot(x="head_gender", y="vaccinations_population_percent", data=CountriesDataEuropeAll)
plt.title("gender head of government - all countries in Europe ",fontsize=10)
plt.ylabel("percent of population",fontsize=10)
plt.xlabel("head of government - gender",fontsize=10)
plt.suptitle(start_time.strftime('%Y %m %d - %-H:%M - Total: World ' + worldtotal_vaccinations_str) + 
             " - Europe " + europetotal_vaccinations_str 
             ,fontsize=10,color = 'gray', y=1.1)

plt.savefig("images/Corona_AllEurope_percent_gender_scatterplot.png",bbox_inches="tight")
plt.show()

# %%
plt.rcParams.update(plt.rcParamsDefault) 
plt.rcParams['figure.figsize'] = (15.0, 10.0)
sns.color_palette("magma")
sns.catplot(x="head_gender", y="total_vaccinations", data=CountriesDataEuropeAll)
plt.title("Gender head of government - all countries in Europe ",fontsize=10,x=0.8)
plt.ylabel("total vaccinations",fontsize=10)
plt.xlabel("head of government - gender",fontsize=10)
plt.suptitle(start_time.strftime('%Y %m %d - %-H:%M - Total: World ' + worldtotal_vaccinations_str) + 
             " - Europe " + europetotal_vaccinations_str 
             ,fontsize=10,color = 'gray', y=1.1)

plt.savefig("images/Corona_AllEurope_gender_scatterplot.png",bbox_inches="tight")
plt.show()

# %%
print(worldtotal_vaccinations_str, plotLatestCountries.shape, europetotal_vaccinations_str, CountriesDataEurope.shape)
# Out:
# 29 493 847 (47, 3) 7 046 611 (32, 21)

# %%
end = datetime.now()
print("Ended: ", end) 
print('Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))
# Out:
# Ended:  2021-01-13 12:57:14.660172
# Time elapsed (hh:mm:ss.ms) 0:00:32.687767

# %%
#The Global State of Democracy Indices
#stata_democracy_indices = "https://www.idea.int/gsod-indices/sites/default/files/gsodi_pv_4.dta"
#df = pd.read_stata(stata_democracy_indices)
