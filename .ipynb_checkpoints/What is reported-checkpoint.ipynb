# %% [markdown]
# # What is reported about covid 19 vaccinations
#
# * [Sweden](#Sweden)
# * [Turkey](#Turkey)
# * [Israel](#Israel)
# * [All](#All)
#
#
#
# ### About
# * [this Notebook](https://github.com/salgo60/CoronaVaccinationCheck/blob/master/What%20is%20reported.ipynb) / [repository](https://github.com/salgo60/CoronaVaccinationCheck)
#
# * we read the data from [github.com/owid/covid-19-data...vaccinations/country_data](https://github.com/owid/covid-19-data/tree/master/public/data/vaccinations/country_data) created by [Our World in Data](https://ourworldindata.org/)
#   * see also [WHO Coronavirus Disease (COVID-19) Dashboard](https://covid19.who.int/)
#
# Interesting is that some countries like [Turkey now has real time reporting](https://covid19asi.saglik.gov.tr/) / [tweet](https://twitter.com/redouad/status/1349688916975230978?s=20)
# * Sweden and death reporting see [svt.se in Swedish](https://www.svt.se/datajournalistik/en-koll-rapporterade-covid-dodsfall/)
#
# ## Why is Sweden underperforming regarding reporting?
#
# * Swedish FHM try to explain why they underperform see [discussion in Swedish](https://community.dataportal.se/topic/77/tillg%C3%A4nglighetsdirektivet-och-publicerade-%C3%B6ppna-data/3?_=1617769671095)

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2021-07-12 18:02:38.309059

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

GITHUB_directory = "https://api.github.com/repos/owid/covid-19-data/contents/public/data/vaccinations/country_data"  
countries = pd.read_json(GITHUB_directory)  
listcountries = []
for index,row in countries.iterrows():
#    print(index, row["name"])
    df = pd.read_csv(row["download_url"])
    listcountries.append(df)
    
allCountriesGitHub = pd.concat(listcountries, axis=0, ignore_index=True) 
allCountriesGitHub = allCountriesGitHub.sort_values(by=['date'],ascending=False)
allCountriesGitHub.reset_index(drop=True, inplace=True)
allCountriesGitHub = allCountriesGitHub[["location","date","vaccine","total_vaccinations","people_vaccinated", \
                                         "people_fully_vaccinated","source_url"]]
allCountriesGitHub.index += 1

# %%
allCountriesGitHub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17041 entries, 1 to 17041
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   location                 17041 non-null  object
#  1   date                     17041 non-null  object
#  2   vaccine                  17041 non-null  object
#  3   total_vaccinations       16871 non-null  float64
#  4   people_vaccinated        16023 non-null  float64
#  5   people_fully_vaccinated  14462 non-null  float64
#  6   source_url               17041 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 932.1+ KB

# %% [markdown]
# <a name="Sweden"></a>

# %% [markdown]
# ## Sweden <a class="anchor" name="Sweden"></a>
# <a name="Sweden"></a>
# * looks like no machinereadable data is available from FHM --> OWiD reads a swedish web page
#    * https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/

# %%
Sweden = allCountriesGitHub[allCountriesGitHub["location"] == "Sweden"]
Sweden[:10]
# Out:
#      location        date                              vaccine  \
# 143    Sweden  2021-07-09  Oxford/AstraZeneca, Pfizer/BioNTech
# 280    Sweden  2021-07-08  Oxford/AstraZeneca, Pfizer/BioNTech
# 378    Sweden  2021-07-07  Oxford/AstraZeneca, Pfizer/BioNTech
# 524    Sweden  2021-07-06  Oxford/AstraZeneca, Pfizer/BioNTech
# 970    Sweden  2021-07-02  Oxford/AstraZeneca, Pfizer/BioNTech
# 1574   Sweden  2021-06-27  Oxford/AstraZeneca, Pfizer/BioNTech
# 2333   Sweden  2021-06-20  Oxford/AstraZeneca, Pfizer/BioNTech
# 3129   Sweden  2021-06-13  Oxford/AstraZeneca, Pfizer/BioNTech
# 3965   Sweden  2021-06-06  Oxford/AstraZeneca, Pfizer/BioNTech
# 4681   Sweden  2021-05-30  Oxford/AstraZeneca, Pfizer/BioNTech
#
#       total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 143            9086607.0          5523876.0                3562731.0
# 280            8951302.0          5438339.0                3512963.0
# 378            8820411.0          5352692.0                3467719.0
# 524            8732503.0          5302083.0                3430420.0
# 970            8168667.0          4999452.0                3169215.0
# 1574           8039870.0          4911494.0                3128376.0
# 2333           7407339.0          4623652.0                2783687.0
# 3129           6638739.0          4321720.0                2317019.0
# 3965           5961202.0          4051764.0                1909438.0
# 4681           5378229.0          3835030.0                1543199.0
#
#                                                                                                                                                                              source_url
# 143   https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 280   https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 378   https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 524   https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 970   https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 1574  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 2333  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 3129  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 3965  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 4681  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/

# %%
Sweden.shape
# Out:
# (32, 7)

# %% [markdown]
# ## Turkey <a class="anchor" id="Turkey"></a>
# Looks like Turkey data is fetched more times per day but just one datapoint is stored per day see [recent commits](https://github.com/owid/covid-19-data/commits/master/public/data/vaccinations/country_data/Turkey.csv) and how they 2020-01-15 ["overwrite" the last 2020-01-15 entry](https://github.com/owid/covid-19-data/commit/77190797443d239c19de1da9acca633541885e85#diff-eb9a3b52782ce32ebd98410b11c22142d8377bdb5a5466a5e7a14718822a5243)
# * [Realtime](https://covid19asi.saglik.gov.tr/)

# %%
Turkey = allCountriesGitHub[allCountriesGitHub["location"] == "Turkey"]
Turkey.shape
# Out:
# (179, 7)

# %%
Turkey[:10]
# Out:
#     location        date                   vaccine  total_vaccinations  \
# 58    Turkey  2021-07-11  Pfizer/BioNTech, Sinovac          58155459.0
# 127   Turkey  2021-07-10  Pfizer/BioNTech, Sinovac          57583424.0
# 187   Turkey  2021-07-09  Pfizer/BioNTech, Sinovac          57248834.0
# 309   Turkey  2021-07-08  Pfizer/BioNTech, Sinovac          56646457.0
# 346   Turkey  2021-07-07  Pfizer/BioNTech, Sinovac          55808670.0
# 527   Turkey  2021-07-06  Pfizer/BioNTech, Sinovac          55004225.0
# 589   Turkey  2021-07-05  Pfizer/BioNTech, Sinovac          54148190.0
# 773   Turkey  2021-07-04  Pfizer/BioNTech, Sinovac          53226310.0
# 860   Turkey  2021-07-03  Pfizer/BioNTech, Sinovac          52479924.0
# 969   Turkey  2021-07-02  Pfizer/BioNTech, Sinovac          52104718.0
#
#      people_vaccinated  people_fully_vaccinated  \
# 58          37811142.0               17350100.0
# 127         37644385.0               17070834.0
# 187         37530250.0               16893992.0
# 309         37318116.0               16639474.0
# 346         37028443.0               16347747.0
# 527         36736718.0               16140197.0
# 589         36416034.0               15962069.0
# 773         36084241.0               15779136.0
# 860         35828964.0               15625651.0
# 969         35673239.0               15522900.0
#
#                             source_url
# 58   https://covid19asi.saglik.gov.tr/
# 127  https://covid19asi.saglik.gov.tr/
# 187  https://covid19asi.saglik.gov.tr/
# 309  https://covid19asi.saglik.gov.tr/
# 346  https://covid19asi.saglik.gov.tr/
# 527  https://covid19asi.saglik.gov.tr/
# 589  https://covid19asi.saglik.gov.tr/
# 773  https://covid19asi.saglik.gov.tr/
# 860  https://covid19asi.saglik.gov.tr/
# 969  https://covid19asi.saglik.gov.tr/

# %% [markdown]
# ## Israel <a class="anchor" id="Israel"></a>

# %%
Israel = allCountriesGitHub[allCountriesGitHub["location"] == "Israel"]
Israel.shape
# Out:
# (205, 7)

# %%
Israel[:10]
# Out:
#     location        date                   vaccine  total_vaccinations  \
# 5     Israel  2021-07-11  Moderna, Pfizer/BioNTech          10923521.0
# 92    Israel  2021-07-10  Moderna, Pfizer/BioNTech          10919381.0
# 186   Israel  2021-07-09  Moderna, Pfizer/BioNTech          10914201.0
# 269   Israel  2021-07-08  Moderna, Pfizer/BioNTech          10901907.0
# 354   Israel  2021-07-07  Moderna, Pfizer/BioNTech          10882886.0
# 521   Israel  2021-07-06  Moderna, Pfizer/BioNTech          10865121.0
# 570   Israel  2021-07-05  Moderna, Pfizer/BioNTech          10844234.0
# 803   Israel  2021-07-04  Moderna, Pfizer/BioNTech          10823751.0
# 816   Israel  2021-07-03  Moderna, Pfizer/BioNTech          10803063.0
# 909   Israel  2021-07-02  Moderna, Pfizer/BioNTech          10800237.0
#
#      people_vaccinated  people_fully_vaccinated  \
# 5            5730022.0                5193499.0
# 92           5728637.0                5190744.0
# 186          5723760.0                5190441.0
# 269          5712769.0                5189138.0
# 354          5696403.0                5186483.0
# 521          5681131.0                5183990.0
# 570          5663434.0                5180800.0
# 803          5645812.0                5177939.0
# 816          5628191.0                5174872.0
# 909          5625603.0                5174634.0
#
#                                                source_url
# 5    https://datadashboard.health.gov.il/COVID-19/general
# 92   https://datadashboard.health.gov.il/COVID-19/general
# 186  https://datadashboard.health.gov.il/COVID-19/general
# 269  https://datadashboard.health.gov.il/COVID-19/general
# 354  https://datadashboard.health.gov.il/COVID-19/general
# 521  https://datadashboard.health.gov.il/COVID-19/general
# 570  https://datadashboard.health.gov.il/COVID-19/general
# 803  https://datadashboard.health.gov.il/COVID-19/general
# 816  https://datadashboard.health.gov.il/COVID-19/general
# 909  https://datadashboard.health.gov.il/COVID-19/general

# %% [markdown]
# ## All countries
# number times reporting data

# %%
allCountriesGitHubCount = allCountriesGitHub["location"].value_counts()
allCountriesGitHubCount = allCountriesGitHubCount.reset_index()
allCountriesGitHubCount.index += 1   
# show number times reported top 100
allCountriesGitHubCount.shape
# Out:
# (219, 2)

# %%
allCountriesGitHubCount[110:140]
# Out:
#                                 index  location
# 111                         Greenland        62
# 112                            Cyprus        61
# 113                            Guinea        61
# 114                            Belize        60
# 115                       Saint Lucia        59
# 116                           Nigeria        58
# 117                             Nepal        57
# 118                    Cayman Islands        56
# 119                              Cuba        52
# 120                              Laos        48
# 121                            Zambia        48
# 122                            Jordan        45
# 123                          Guernsey        42
# 124                          Pakistan        39
# 125                          Dominica        35
# 126                         Singapore        34
# 127                            Sweden        32
# 128               Antigua and Barbuda        32
# 129                        Costa Rica        32
# 130                            Rwanda        31
# 131                           Bermuda        30
# 132                           Grenada        27
# 133                       Netherlands        27
# 134                          Honduras        26
# 135                           Andorra        25
# 136                            Guyana        25
# 137                          Botswana        25
# 138  Saint Vincent and the Grenadines        25
# 139                             Egypt        24
# 140                 Equatorial Guinea        24

# %%
#Latest reported
allCountriesGitHub[:10]
# Out:
#        location        date  \
# 1      Zimbabwe  2021-07-11
# 2       Hungary  2021-07-11
# 3         Italy  2021-07-11
# 4      Slovenia  2021-07-11
# 5        Israel  2021-07-11
# 6   Isle of Man  2021-07-11
# 7     Indonesia  2021-07-11
# 8   South Korea  2021-07-11
# 9         India  2021-07-11
# 10    Hong Kong  2021-07-11
#
#                                                                                         vaccine  \
# 1                                                                             Sinopharm/Beijing
# 2   Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V
# 3                                 Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 4                                                           Oxford/AstraZeneca, Pfizer/BioNTech
# 5                                                                      Moderna, Pfizer/BioNTech
# 6                                                           Oxford/AstraZeneca, Pfizer/BioNTech
# 7                                                                   Oxford/AstraZeneca, Sinovac
# 8                                 Oxford/AstraZeneca, Pfizer/BioNTech, Johnson&Johnson, Moderna
# 9                                                        Covaxin, Oxford/AstraZeneca, Sputnik V
# 10                                                                     Pfizer/BioNTech, Sinovac
#
#     total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 1            1491397.0           895980.0                 595417.0
# 2                  NaN          5538557.0                5175503.0
# 3           57616037.0         35843579.0               23040048.0
# 4            1587535.0           847797.0                 739738.0
# 5           10923521.0          5730022.0                5193499.0
# 6             114190.0            64153.0                  50037.0
# 7           51278367.0         36267019.0               15011348.0
# 8           20330660.0         15586937.0                5873409.0
# 9          377352501.0        304018852.0               73333649.0
# 10           4396625.0          2591777.0                1804848.0
#
#                                                                                                            source_url
# 1                                                             https://twitter.com/MoHCCZim/status/1414333341600567301
# 2                   https://koronavirus.gov.hu//cikkek/5-millio-538-ezer-beoltott-102-az-uj-fertozott-elhunyt-3-beteg
# 3   https://raw.githubusercontent.com/italia/covid19-opendata-vaccini/master/dati/somministrazioni-vaccini-latest.csv
# 4                                                                             https://covid-19.sledilnik.org/en/stats
# 5                                                                https://datadashboard.health.gov.il/COVID-19/general
# 6                                         https://covid19.gov.im/general-information/covid-19-vaccination-statistics/
# 7                                                                              https://vaksin.kemkes.go.id/#/vaccines
# 8                                                                                             https://ncv.kdca.go.kr/
# 9                                                                                           https://www.mohfw.gov.in/
# 10                                                                       https://www.covidvaccine.gov.hk/en/dashboard

# %%
allCountriesGitHub.shape
# Out:
# (17041, 7)
