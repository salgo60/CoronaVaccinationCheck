# %% [markdown]
# # What is reported about covid 19 vaccinations
#
# * [Sweden](#Sweden)
# * [Turkey](#Turkey)
# * [Israel](#Israel)
# * [All](#All)
#
#
#
# ### About
# * [this Notebook](https://github.com/salgo60/CoronaVaccinationCheck/blob/master/What%20is%20reported.ipynb) / [repository](https://github.com/salgo60/CoronaVaccinationCheck)
#
# * we read the data from [github.com/owid/covid-19-data...vaccinations/country_data](https://github.com/owid/covid-19-data/tree/master/public/data/vaccinations/country_data) created by [Our World in Data](https://ourworldindata.org/)
#   * see also [WHO Coronavirus Disease (COVID-19) Dashboard](https://covid19.who.int/)
#
# Interesting is that some countries like [Turkey now has real time reporting](https://covid19asi.saglik.gov.tr/) / [tweet](https://twitter.com/redouad/status/1349688916975230978?s=20)
# * Sweden and death reporting see [svt.se in Swedish](https://www.svt.se/datajournalistik/en-koll-rapporterade-covid-dodsfall/)
#
# ## Why is Sweden underperforming regarding reporting?
#
# * Swedish FHM try to explain why they underperform see [discussion in Swedish](https://community.dataportal.se/topic/77/tillg%C3%A4nglighetsdirektivet-och-publicerade-%C3%B6ppna-data/3?_=1617769671095)

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2021-05-19 10:32:48.054827

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

GITHUB_directory = "https://api.github.com/repos/owid/covid-19-data/contents/public/data/vaccinations/country_data"  
countries = pd.read_json(GITHUB_directory)  
listcountries = []
for index,row in countries.iterrows():
#    print(index, row["name"])
    df = pd.read_csv(row["download_url"])
    listcountries.append(df)
    
allCountriesGitHub = pd.concat(listcountries, axis=0, ignore_index=True) 
allCountriesGitHub = allCountriesGitHub.sort_values(by=['date'],ascending=False)
allCountriesGitHub.reset_index(drop=True, inplace=True)
allCountriesGitHub = allCountriesGitHub[["location","date","vaccine","total_vaccinations","people_vaccinated", \
                                         "people_fully_vaccinated","source_url"]]
allCountriesGitHub.index += 1

# %% [markdown]
# <a name="Sweden"></a>

# %% [markdown]
# ## Sweden <a class="anchor" name="Sweden"></a>
# <a name="Sweden"></a>
# * looks like no machinereadable data is available from FHM --> OWiD reads a swedish web page
#    * https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/

# %%
Sweden = allCountriesGitHub[allCountriesGitHub["location"] == "Sweden"]
Sweden[:10]
# Out:
#      location        date                              vaccine  \
# 299    Sweden  2021-05-14  Oxford/AstraZeneca, Pfizer/BioNTech
# 488    Sweden  2021-05-12  Oxford/AstraZeneca, Pfizer/BioNTech
# 559    Sweden  2021-05-11  Oxford/AstraZeneca, Pfizer/BioNTech
# 1058   Sweden  2021-05-07  Oxford/AstraZeneca, Pfizer/BioNTech
# 1160   Sweden  2021-05-06  Oxford/AstraZeneca, Pfizer/BioNTech
# 1521   Sweden  2021-05-02  Oxford/AstraZeneca, Pfizer/BioNTech
# 2244   Sweden  2021-04-25  Oxford/AstraZeneca, Pfizer/BioNTech
# 2996   Sweden  2021-04-18  Oxford/AstraZeneca, Pfizer/BioNTech
# 4457   Sweden  2021-04-04  Oxford/AstraZeneca, Pfizer/BioNTech
# 5136   Sweden  2021-03-28  Oxford/AstraZeneca, Pfizer/BioNTech
#
#       total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 299            4177688.0          3194265.0                 983423.0
# 488            3957465.0          3060144.0                 897321.0
# 559            3909862.0          3026101.0                 883761.0
# 1058           3679451.0          2852689.0                 826762.0
# 1160           3563609.0          2769411.0                 794198.0
# 1521           3505173.0          2724577.0                 780596.0
# 2244           3118750.0          2365123.0                 753627.0
# 2996           2689918.0          1974083.0                 715835.0
# 4457           1879009.0          1319972.0                 559037.0
# 5136           1616178.0          1124273.0                 491905.0
#
#                                                                                                                                                                              source_url
# 299   https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 488   https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 559   https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 1058  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 1160  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 1521  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 2244  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 2996  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 4457  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 5136  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/

# %%
Sweden.shape
# Out:
# (23, 7)

# %% [markdown]
# ## Turkey <a class="anchor" id="Turkey"></a>
# Looks like Turkey data is fetched more times per day but just one datapoint is stored per day see [recent commits](https://github.com/owid/covid-19-data/commits/master/public/data/vaccinations/country_data/Turkey.csv) and how they 2020-01-15 ["overwrite" the last 2020-01-15 entry](https://github.com/owid/covid-19-data/commit/77190797443d239c19de1da9acca633541885e85#diff-eb9a3b52782ce32ebd98410b11c22142d8377bdb5a5466a5e7a14718822a5243)
# * [Realtime](https://covid19asi.saglik.gov.tr/)

# %%
Turkey = allCountriesGitHub[allCountriesGitHub["location"] == "Turkey"]
Turkey.shape
# Out:
# (124, 7)

# %%
Turkey[:10]
# Out:
#     location        date                   vaccine  total_vaccinations  \
# 16    Turkey  2021-05-17  Pfizer/BioNTech, Sinovac          25950934.0
# 124   Turkey  2021-05-16  Pfizer/BioNTech, Sinovac          25772743.0
# 197   Turkey  2021-05-15  Pfizer/BioNTech, Sinovac          25687427.0
# 263   Turkey  2021-05-14  Pfizer/BioNTech, Sinovac          25561998.0
# 409   Turkey  2021-05-13  Pfizer/BioNTech, Sinovac          25402277.0
# 468   Turkey  2021-05-12  Pfizer/BioNTech, Sinovac          25348875.0
# 614   Turkey  2021-05-11  Pfizer/BioNTech, Sinovac          25178674.0
# 722   Turkey  2021-05-10  Pfizer/BioNTech, Sinovac          25018078.0
# 865   Turkey  2021-05-09  Pfizer/BioNTech, Sinovac          24918773.0
# 916   Turkey  2021-05-08  Pfizer/BioNTech, Sinovac          24853353.0
#
#      people_vaccinated  people_fully_vaccinated  \
# 16          14986982.0               10963952.0
# 124         14947740.0               10825003.0
# 197         14895052.0               10792375.0
# 263         14814316.0               10747682.0
# 409         14732527.0               10669750.0
# 468         14711273.0               10637602.0
# 614         14660551.0               10518123.0
# 722         14618167.0               10399911.0
# 865         14585980.0               10332793.0
# 916         14545524.0               10307829.0
#
#                             source_url
# 16   https://covid19asi.saglik.gov.tr/
# 124  https://covid19asi.saglik.gov.tr/
# 197  https://covid19asi.saglik.gov.tr/
# 263  https://covid19asi.saglik.gov.tr/
# 409  https://covid19asi.saglik.gov.tr/
# 468  https://covid19asi.saglik.gov.tr/
# 614  https://covid19asi.saglik.gov.tr/
# 722  https://covid19asi.saglik.gov.tr/
# 865  https://covid19asi.saglik.gov.tr/
# 916  https://covid19asi.saglik.gov.tr/

# %% [markdown]
# ## Israel <a class="anchor" id="Israel"></a>

# %%
Israel = allCountriesGitHub[allCountriesGitHub["location"] == "Israel"]
Israel.shape
# Out:
# (150, 7)

# %%
Israel[:10]
# Out:
#     location        date                   vaccine  total_vaccinations  \
# 41    Israel  2021-05-17  Moderna, Pfizer/BioNTech          10530337.0
# 97    Israel  2021-05-16  Moderna, Pfizer/BioNTech          10529524.0
# 218   Israel  2021-05-15  Moderna, Pfizer/BioNTech          10527973.0
# 312   Israel  2021-05-14  Moderna, Pfizer/BioNTech          10527674.0
# 396   Israel  2021-05-13  Moderna, Pfizer/BioNTech          10525597.0
# 511   Israel  2021-05-12  Moderna, Pfizer/BioNTech          10520395.0
# 601   Israel  2021-05-11  Moderna, Pfizer/BioNTech          10515518.0
# 682   Israel  2021-05-10  Moderna, Pfizer/BioNTech          10509493.0
# 853   Israel  2021-05-09  Moderna, Pfizer/BioNTech          10502235.0
# 945   Israel  2021-05-08  Moderna, Pfizer/BioNTech          10494868.0
#
#      people_vaccinated  people_fully_vaccinated  \
# 41           5432695.0                5097642.0
# 97           5432515.0                5097009.0
# 218          5432092.0                5095881.0
# 312          5431963.0                5095711.0
# 396          5431199.0                5094398.0
# 511          5429394.0                5091001.0
# 601          5427596.0                5087922.0
# 682          5425206.0                5084287.0
# 853          5422458.0                5079777.0
# 945          5419706.0                5075162.0
#
#                                                source_url
# 41   https://datadashboard.health.gov.il/COVID-19/general
# 97   https://datadashboard.health.gov.il/COVID-19/general
# 218  https://datadashboard.health.gov.il/COVID-19/general
# 312  https://datadashboard.health.gov.il/COVID-19/general
# 396  https://datadashboard.health.gov.il/COVID-19/general
# 511  https://datadashboard.health.gov.il/COVID-19/general
# 601  https://datadashboard.health.gov.il/COVID-19/general
# 682  https://datadashboard.health.gov.il/COVID-19/general
# 853  https://datadashboard.health.gov.il/COVID-19/general
# 945  https://datadashboard.health.gov.il/COVID-19/general

# %% [markdown]
# ## All countries
# number times reporting data

# %%
allCountriesGitHubCount = allCountriesGitHub["location"].value_counts()
allCountriesGitHubCount = allCountriesGitHubCount.reset_index()
allCountriesGitHubCount.index += 1   
# show number times reported top 100
allCountriesGitHubCount[100:140]
# Out:
#                                 index  location
# 101                    Faeroe Islands        38
# 102               Trinidad and Tobago        37
# 103                    Cayman Islands        36
# 104                           Namibia        35
# 105                       Saint Lucia        35
# 106                           Georgia        35
# 107                             Aruba        33
# 108                            Guinea        32
# 109                   North Macedonia        31
# 110                            Rwanda        31
# 111                          Suriname        30
# 112                            Cyprus        28
# 113                         Palestine        27
# 114                             Nepal        27
# 115                         Greenland        25
# 116                        Costa Rica        24
# 117                            Sweden        23
# 118                            Zambia        22
# 119                          Dominica        22
# 120                           Bermuda        21
# 121                         Singapore        21
# 122                        Kazakhstan        21
# 123                           Grenada        20
# 124                       Netherlands        19
# 125                           Andorra        19
# 126                          Ethiopia        19
# 127                  French Polynesia        17
# 128                             Kenya        16
# 129                             Ghana        15
# 130                          Pakistan        15
# 131                            Jordan        15
# 132                              Iran        15
# 133                     New Caledonia        14
# 134                      Sierra Leone        13
# 135                   Northern Cyprus        12
# 136  Saint Vincent and the Grenadines        12
# 137               Antigua and Barbuda        12
# 138                            Guyana        11
# 139                            Kuwait        11
# 140                          Guernsey        11

# %%
#Latest reported
allCountriesGitHub[:10]
# Out:
#                location        date  \
# 1              Zimbabwe  2021-05-17
# 2               Uruguay  2021-05-17
# 3               Albania  2021-05-17
# 4                Jersey  2021-05-17
# 5   Trinidad and Tobago  2021-05-17
# 6               Finland  2021-05-17
# 7            Kazakhstan  2021-05-17
# 8               Tunisia  2021-05-17
# 9                Kosovo  2021-05-17
# 10             Slovenia  2021-05-17
#
#                                                     vaccine  \
# 1                                         Sinopharm/Beijing
# 2              Sinovac, Pfizer/BioNTech, Oxford/AstraZeneca
# 3   Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V
# 4                       Oxford/AstraZeneca, Pfizer/BioNTech
# 5                                        Oxford/AstraZeneca
# 6              Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 7                     QazVac, Sinopharm/HayatVax, Sputnik V
# 8                       Pfizer/BioNTech, Sinovac, Sputnik V
# 9                                        Oxford/AstraZeneca
# 10                      Oxford/AstraZeneca, Pfizer/BioNTech
#
#     total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 1             814258.0           591808.0                 222450.0
# 2            2348501.0          1401145.0                 947356.0
# 3             680083.0           456980.0                 223103.0
# 4              94574.0            55684.0                  38890.0
# 5              61850.0            60671.0                   1179.0
# 6            2424693.0          2133397.0                 291296.0
# 7            2603997.0          1844938.0                 759059.0
# 8             823614.0           628107.0                 195507.0
# 9              46097.0            46097.0                      0.0
# 10            854388.0           560106.0                 294282.0
#
#                                                                                                                                source_url
# 1                                                                                 https://twitter.com/MoHCCZim/status/1394356078247399426
# 2                                                                                                 https://monitor.uruguaysevacuna.gub.uy/
# 3                                                                 https://shendetesia.gov.al/vaksinimi-anticovid-kryhen-680083-vaksinime/
# 4                                                              https://www.gov.je/Datasets/ListOpenData?ListName=COVID19Weekly&clean=true
# 5                                                              https://experience.arcgis.com/experience/59226cacd2b441c7a939dca13f832112/
# 6   https://sampo.thl.fi/pivot/prod/en/vaccreg/cov19cov/fact_cov19cov?column=measure-533185.533172.433796.533175&row=cov_vac_dose-533174L
# 7                                                                                                         https://www.coronavirus2020.kz/
# 8                                                                     https://www.facebook.com/santetunisie.rns.tn/posts/4140999415939131
# 9                                                              https://www.facebook.com/Ministria.Shendetesise.RKS/posts/1993116074179303
# 10                                                                                                https://covid-19.sledilnik.org/en/stats

# %%
allCountriesGitHub.shape
# Out:
# (10741, 7)
