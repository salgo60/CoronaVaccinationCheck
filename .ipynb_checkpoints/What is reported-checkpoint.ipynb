# %% [markdown]
# # What is reported about covid 19 vaccinations
#
# * [Sweden](#Sweden)
# * [Turkey](#Turkey)
# * [Israel](#Israel)
# * [All](#All)
#
#
#
# ### About
# * [this Notebook](https://github.com/salgo60/CoronaVaccinationCheck/blob/master/What%20is%20reported.ipynb) / [repository](https://github.com/salgo60/CoronaVaccinationCheck)
#
# * we read the data from [github.com/owid/covid-19-data...vaccinations/country_data](https://github.com/owid/covid-19-data/tree/master/public/data/vaccinations/country_data) created by [Our World in Data](https://ourworldindata.org/)
#   * see also [WHO Coronavirus Disease (COVID-19) Dashboard](https://covid19.who.int/)
#
# Interesting is that some countries like [Turkey now has real time reporting](https://covid19asi.saglik.gov.tr/) / [tweet](https://twitter.com/redouad/status/1349688916975230978?s=20)
#
# ## Why is Sweden underperforming regarding reporting?
#
# * Swedish FHM try to explain why they underperform see [discussion in Swedish](https://community.dataportal.se/topic/77/tillg%C3%A4nglighetsdirektivet-och-publicerade-%C3%B6ppna-data/3?_=1617769671095)

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2021-05-15 16:14:48.294408

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

GITHUB_directory = "https://api.github.com/repos/owid/covid-19-data/contents/public/data/vaccinations/country_data"  
countries = pd.read_json(GITHUB_directory)  
listcountries = []
for index,row in countries.iterrows():
#    print(index, row["name"])
    df = pd.read_csv(row["download_url"])
    listcountries.append(df)
    
allCountriesGitHub = pd.concat(listcountries, axis=0, ignore_index=True) 
allCountriesGitHub = allCountriesGitHub.sort_values(by=['date'],ascending=False)
allCountriesGitHub.reset_index(drop=True, inplace=True)
allCountriesGitHub = allCountriesGitHub[["location","date","vaccine","total_vaccinations","people_vaccinated", \
                                         "people_fully_vaccinated","source_url"]]
allCountriesGitHub.index += 1

# %% [markdown]
# <a name="Sweden"></a>

# %% [markdown]
# ## Sweden <a class="anchor" name="Sweden"></a>
# <a name="Sweden"></a>
# * looks like no machinereadable data is available from FHM --> OWiD reads a swedish web page
#    * https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/

# %%
Sweden = allCountriesGitHub[allCountriesGitHub["location"] == "Sweden"]
Sweden[:10]
# Out:
#      location        date                              vaccine  \
# 36     Sweden  2021-05-14  Oxford/AstraZeneca, Pfizer/BioNTech
# 185    Sweden  2021-05-12  Oxford/AstraZeneca, Pfizer/BioNTech
# 360    Sweden  2021-05-11  Oxford/AstraZeneca, Pfizer/BioNTech
# 692    Sweden  2021-05-07  Oxford/AstraZeneca, Pfizer/BioNTech
# 868    Sweden  2021-05-06  Oxford/AstraZeneca, Pfizer/BioNTech
# 1278   Sweden  2021-05-02  Oxford/AstraZeneca, Pfizer/BioNTech
# 2046   Sweden  2021-04-25  Oxford/AstraZeneca, Pfizer/BioNTech
# 2774   Sweden  2021-04-18  Oxford/AstraZeneca, Pfizer/BioNTech
# 4197   Sweden  2021-04-04  Oxford/AstraZeneca, Pfizer/BioNTech
# 4889   Sweden  2021-03-28  Oxford/AstraZeneca, Pfizer/BioNTech
#
#       total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 36             4177688.0          3194265.0                 983423.0
# 185            3957465.0          3060144.0                 897321.0
# 360            3909862.0          3026101.0                 883761.0
# 692            3679451.0          2852689.0                 826762.0
# 868            3563609.0          2769411.0                 794198.0
# 1278           3505173.0          2724577.0                 780596.0
# 2046           3118750.0          2365123.0                 753627.0
# 2774           2689918.0          1974083.0                 715835.0
# 4197           1879009.0          1319972.0                 559037.0
# 4889           1616178.0          1124273.0                 491905.0
#
#                                                                                                                                                                              source_url
# 36    https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 185   https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 360   https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 692   https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 868   https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 1278  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 2046  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 2774  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 4197  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 4889  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/

# %%
Sweden.shape
# Out:
# (23, 7)

# %% [markdown]
# ## Turkey <a class="anchor" id="Turkey"></a>
# Looks like Turkey data is fetched more times per day but just one datapoint is stored per day see [recent commits](https://github.com/owid/covid-19-data/commits/master/public/data/vaccinations/country_data/Turkey.csv) and how they 2020-01-15 ["overwrite" the last 2020-01-15 entry](https://github.com/owid/covid-19-data/commit/77190797443d239c19de1da9acca633541885e85#diff-eb9a3b52782ce32ebd98410b11c22142d8377bdb5a5466a5e7a14718822a5243)
# * [Realtime](https://covid19asi.saglik.gov.tr/)

# %%
Turkey = allCountriesGitHub[allCountriesGitHub["location"] == "Turkey"]
Turkey.shape
# Out:
# (121, 7)

# %%
Turkey[:10]
# Out:
#     location        date                   vaccine  total_vaccinations  \
# 61    Turkey  2021-05-14  Pfizer/BioNTech, Sinovac          25561998.0
# 70    Turkey  2021-05-13  Pfizer/BioNTech, Sinovac          25402277.0
# 270   Turkey  2021-05-12  Pfizer/BioNTech, Sinovac          25348875.0
# 277   Turkey  2021-05-11  Pfizer/BioNTech, Sinovac          25178674.0
# 433   Turkey  2021-05-10  Pfizer/BioNTech, Sinovac          25018078.0
# 565   Turkey  2021-05-09  Pfizer/BioNTech, Sinovac          24918773.0
# 654   Turkey  2021-05-08  Pfizer/BioNTech, Sinovac          24853353.0
# 690   Turkey  2021-05-07  Pfizer/BioNTech, Sinovac          24691044.0
# 819   Turkey  2021-05-06  Pfizer/BioNTech, Sinovac          24467719.0
# 984   Turkey  2021-05-05  Pfizer/BioNTech, Sinovac          24103883.0
#
#      people_vaccinated  people_fully_vaccinated  \
# 61          14814316.0               10747682.0
# 70          14732527.0               10669750.0
# 270         14711273.0               10637602.0
# 277         14660551.0               10518123.0
# 433         14618167.0               10399911.0
# 565         14585980.0               10332793.0
# 654         14545524.0               10307829.0
# 690         14476881.0               10214163.0
# 819         14391595.0               10076124.0
# 984         14264014.0                9839869.0
#
#                             source_url
# 61   https://covid19asi.saglik.gov.tr/
# 70   https://covid19asi.saglik.gov.tr/
# 270  https://covid19asi.saglik.gov.tr/
# 277  https://covid19asi.saglik.gov.tr/
# 433  https://covid19asi.saglik.gov.tr/
# 565  https://covid19asi.saglik.gov.tr/
# 654  https://covid19asi.saglik.gov.tr/
# 690  https://covid19asi.saglik.gov.tr/
# 819  https://covid19asi.saglik.gov.tr/
# 984  https://covid19asi.saglik.gov.tr/

# %% [markdown]
# ## Israel <a class="anchor" id="Israel"></a>

# %%
Israel = allCountriesGitHub[allCountriesGitHub["location"] == "Israel"]
Israel.shape
# Out:
# (147, 7)

# %%
Israel[:10]
# Out:
#     location        date                   vaccine  total_vaccinations  \
# 41    Israel  2021-05-14  Moderna, Pfizer/BioNTech          10527233.0
# 101   Israel  2021-05-13  Moderna, Pfizer/BioNTech          10525187.0
# 215   Israel  2021-05-12  Moderna, Pfizer/BioNTech          10520022.0
# 329   Israel  2021-05-11  Moderna, Pfizer/BioNTech          10515265.0
# 439   Israel  2021-05-10  Moderna, Pfizer/BioNTech          10509251.0
# 509   Israel  2021-05-09  Moderna, Pfizer/BioNTech          10501994.0
# 637   Israel  2021-05-08  Moderna, Pfizer/BioNTech          10494627.0
# 765   Israel  2021-05-07  Moderna, Pfizer/BioNTech          10494038.0
# 838   Israel  2021-05-06  Moderna, Pfizer/BioNTech          10490109.0
# 945   Israel  2021-05-05  Moderna, Pfizer/BioNTech          10483769.0
#
#      people_vaccinated  people_fully_vaccinated  \
# 41           5431678.0                5095555.0
# 101          5430930.0                5094257.0
# 215          5429152.0                5090870.0
# 329          5427458.0                5087807.0
# 439          5425067.0                5084184.0
# 509          5422320.0                5079674.0
# 637          5419568.0                5075059.0
# 765          5419400.0                5074638.0
# 838          5417745.0                5072364.0
# 945          5414310.0                5069459.0
#
#                                                source_url
# 41   https://datadashboard.health.gov.il/COVID-19/general
# 101  https://datadashboard.health.gov.il/COVID-19/general
# 215  https://datadashboard.health.gov.il/COVID-19/general
# 329  https://datadashboard.health.gov.il/COVID-19/general
# 439  https://datadashboard.health.gov.il/COVID-19/general
# 509  https://datadashboard.health.gov.il/COVID-19/general
# 637  https://datadashboard.health.gov.il/COVID-19/general
# 765  https://datadashboard.health.gov.il/COVID-19/general
# 838  https://datadashboard.health.gov.il/COVID-19/general
# 945  https://datadashboard.health.gov.il/COVID-19/general

# %% [markdown]
# ## All countries
# number times reporting data

# %%
allCountriesGitHubCount = allCountriesGitHub["location"].value_counts()
allCountriesGitHubCount = allCountriesGitHubCount.reset_index()
allCountriesGitHubCount.index += 1   
# show number times reported top 100
allCountriesGitHubCount[100:140]
# Out:
#                                 index  location
# 101                       El Salvador        36
# 102                           Nigeria        35
# 103               Trinidad and Tobago        34
# 104                           Georgia        33
# 105                       Saint Lucia        33
# 106                            Guinea        32
# 107                             Aruba        31
# 108                            Rwanda        31
# 109                   North Macedonia        30
# 110                          Suriname        28
# 111                         Palestine        27
# 112                           Namibia        27
# 113                            Cyprus        26
# 114                             Nepal        26
# 115                        Costa Rica        24
# 116                         Greenland        24
# 117                            Sweden        23
# 118                          Dominica        22
# 119                         Singapore        21
# 120                           Bermuda        21
# 121                            Zambia        20
# 122                           Grenada        20
# 123                           Andorra        19
# 124                       Netherlands        19
# 125                        Kazakhstan        18
# 126                          Ethiopia        17
# 127                  French Polynesia        17
# 128                             Kenya        16
# 129                          Pakistan        15
# 130                             Ghana        15
# 131                              Iran        15
# 132                            Jordan        15
# 133                     New Caledonia        14
# 134                      Sierra Leone        13
# 135               Antigua and Barbuda        12
# 136  Saint Vincent and the Grenadines        12
# 137                   Northern Cyprus        11
# 138                            Guyana        11
# 139                          Guernsey        11
# 140                            Kuwait        10

# %%
#Latest reported
allCountriesGitHub[:10]
# Out:
#                 location        date  \
# 1               Zimbabwe  2021-05-14
# 2         Cayman Islands  2021-05-14
# 3              Greenland  2021-05-14
# 4                Bahrain  2021-05-14
# 5    Trinidad and Tobago  2021-05-14
# 6                Estonia  2021-05-14
# 7              Hong Kong  2021-05-14
# 8   United Arab Emirates  2021-05-14
# 9              Sri Lanka  2021-05-14
# 10               Uruguay  2021-05-14
#
#                                                                                vaccine  \
# 1                                                                    Sinopharm/Beijing
# 2                                                  Oxford/AstraZeneca, Pfizer/BioNTech
# 3                                                                      Pfizer/BioNTech
# 4                    Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V
# 5                                                                   Oxford/AstraZeneca
# 6                                         Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 7                                                             Pfizer/BioNTech, Sinovac
# 8   Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V
# 9                                                Oxford/AstraZeneca, Sinopharm/Beijing
# 10                                        Sinovac, Pfizer/BioNTech, Oxford/AstraZeneca
#
#     total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 1             775241.0           571460.0                 203781.0
# 2              73721.0            39792.0                  33921.0
# 3              16268.0            10222.0                   6046.0
# 4            1447963.0           826748.0                 621215.0
# 5              61848.0            60669.0                   1179.0
# 6             574891.0           397246.0                 177645.0
# 7            1888416.0          1138055.0                 750361.0
# 8           11445680.0                NaN                      NaN
# 9            1384079.0          1140122.0                 243957.0
# 10           2247016.0          1318558.0                 928458.0
#
#                                                                                  source_url
# 1                                   https://twitter.com/MoHCCZim/status/1393292518318542848
# 2                                          https://www.exploregov.ky/coronavirus-statistics
# 3                                   https://corona.nun.gl/emner/statistik/antal_vaccinerede
# 4                                                            https://healthalert.gov.bh/en/
# 5                https://experience.arcgis.com/experience/59226cacd2b441c7a939dca13f832112/
# 6                                                              https://opendata.digilugu.ee
# 7                                              https://www.covidvaccine.gov.hk/en/dashboard
# 8                                                            http://covid19.ncema.gov.ae/en
# 9   https://www.epid.gov.lk/web/images/pdf/corona_virus_report/sitrep-sl-en-14-05_10_21.pdf
# 10                                                  https://monitor.uruguaysevacuna.gub.uy/

# %%
allCountriesGitHub.shape
# Out:
# (10460, 7)
