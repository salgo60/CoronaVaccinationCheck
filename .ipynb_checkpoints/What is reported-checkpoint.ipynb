# %% [markdown]
# # What is reported about covid 19 vaccinations
#
# * [Sweden](#Sweden)
# * [Turkey](#Turkey)
# * [Israel](#Israel)
# * [All](#All)
#
#
#
# ### About
# * [this Notebook](https://github.com/salgo60/CoronaVaccinationCheck/blob/master/What%20is%20reported.ipynb) / [repository](https://github.com/salgo60/CoronaVaccinationCheck)
#
# * we read the data from [github.com/owid/covid-19-data...vaccinations/country_data](https://github.com/owid/covid-19-data/tree/master/public/data/vaccinations/country_data) created by [Our World in Data](https://ourworldindata.org/)
#   * see also [WHO Coronavirus Disease (COVID-19) Dashboard](https://covid19.who.int/)
#
# Interesting is that some countries like [Turkey now has real time reporting](https://covid19asi.saglik.gov.tr/) / [tweet](https://twitter.com/redouad/status/1349688916975230978?s=20)
# * Sweden and death reporting see [svt.se in Swedish](https://www.svt.se/datajournalistik/en-koll-rapporterade-covid-dodsfall/)
#
# ## Why is Sweden underperforming regarding reporting?
#
# * Swedish FHM try to explain why they underperform see [discussion in Swedish](https://community.dataportal.se/topic/77/tillg%C3%A4nglighetsdirektivet-och-publicerade-%C3%B6ppna-data/3?_=1617769671095)

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2021-05-17 13:47:05.773484

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

GITHUB_directory = "https://api.github.com/repos/owid/covid-19-data/contents/public/data/vaccinations/country_data"  
countries = pd.read_json(GITHUB_directory)  
listcountries = []
for index,row in countries.iterrows():
#    print(index, row["name"])
    df = pd.read_csv(row["download_url"])
    listcountries.append(df)
    
allCountriesGitHub = pd.concat(listcountries, axis=0, ignore_index=True) 
allCountriesGitHub = allCountriesGitHub.sort_values(by=['date'],ascending=False)
allCountriesGitHub.reset_index(drop=True, inplace=True)
allCountriesGitHub = allCountriesGitHub[["location","date","vaccine","total_vaccinations","people_vaccinated", \
                                         "people_fully_vaccinated","source_url"]]
allCountriesGitHub.index += 1

# %% [markdown]
# <a name="Sweden"></a>

# %% [markdown]
# ## Sweden <a class="anchor" name="Sweden"></a>
# <a name="Sweden"></a>
# * looks like no machinereadable data is available from FHM --> OWiD reads a swedish web page
#    * https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/

# %%
Sweden = allCountriesGitHub[allCountriesGitHub["location"] == "Sweden"]
Sweden[:10]
# Out:
#      location        date                              vaccine  \
# 190    Sweden  2021-05-14  Oxford/AstraZeneca, Pfizer/BioNTech
# 382    Sweden  2021-05-12  Oxford/AstraZeneca, Pfizer/BioNTech
# 518    Sweden  2021-05-11  Oxford/AstraZeneca, Pfizer/BioNTech
# 864    Sweden  2021-05-07  Oxford/AstraZeneca, Pfizer/BioNTech
# 1022   Sweden  2021-05-06  Oxford/AstraZeneca, Pfizer/BioNTech
# 1464   Sweden  2021-05-02  Oxford/AstraZeneca, Pfizer/BioNTech
# 2177   Sweden  2021-04-25  Oxford/AstraZeneca, Pfizer/BioNTech
# 2926   Sweden  2021-04-18  Oxford/AstraZeneca, Pfizer/BioNTech
# 4397   Sweden  2021-04-04  Oxford/AstraZeneca, Pfizer/BioNTech
# 5017   Sweden  2021-03-28  Oxford/AstraZeneca, Pfizer/BioNTech
#
#       total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 190            4177688.0          3194265.0                 983423.0
# 382            3957465.0          3060144.0                 897321.0
# 518            3909862.0          3026101.0                 883761.0
# 864            3679451.0          2852689.0                 826762.0
# 1022           3563609.0          2769411.0                 794198.0
# 1464           3505173.0          2724577.0                 780596.0
# 2177           3118750.0          2365123.0                 753627.0
# 2926           2689918.0          1974083.0                 715835.0
# 4397           1879009.0          1319972.0                 559037.0
# 5017           1616178.0          1124273.0                 491905.0
#
#                                                                                                                                                                              source_url
# 190   https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 382   https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 518   https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 864   https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 1022  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 1464  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 2177  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 2926  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 4397  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/
# 5017  https://www.folkhalsomyndigheten.se/smittskydd-beredskap/utbrott/aktuella-utbrott/covid-19/vaccination-mot-covid-19/statistik/statistik-over-registrerade-vaccinationer-covid-19/

# %%
Sweden.shape
# Out:
# (23, 7)

# %% [markdown]
# ## Turkey <a class="anchor" id="Turkey"></a>
# Looks like Turkey data is fetched more times per day but just one datapoint is stored per day see [recent commits](https://github.com/owid/covid-19-data/commits/master/public/data/vaccinations/country_data/Turkey.csv) and how they 2020-01-15 ["overwrite" the last 2020-01-15 entry](https://github.com/owid/covid-19-data/commit/77190797443d239c19de1da9acca633541885e85#diff-eb9a3b52782ce32ebd98410b11c22142d8377bdb5a5466a5e7a14718822a5243)
# * [Realtime](https://covid19asi.saglik.gov.tr/)

# %%
Turkey = allCountriesGitHub[allCountriesGitHub["location"] == "Turkey"]
Turkey.shape
# Out:
# (123, 7)

# %%
Turkey[:10]
# Out:
#     location        date                   vaccine  total_vaccinations  \
# 51    Turkey  2021-05-16  Pfizer/BioNTech, Sinovac          25772743.0
# 104   Turkey  2021-05-15  Pfizer/BioNTech, Sinovac          25687427.0
# 196   Turkey  2021-05-14  Pfizer/BioNTech, Sinovac          25561998.0
# 307   Turkey  2021-05-13  Pfizer/BioNTech, Sinovac          25402277.0
# 415   Turkey  2021-05-12  Pfizer/BioNTech, Sinovac          25348875.0
# 468   Turkey  2021-05-11  Pfizer/BioNTech, Sinovac          25178674.0
# 664   Turkey  2021-05-10  Pfizer/BioNTech, Sinovac          25018078.0
# 673   Turkey  2021-05-09  Pfizer/BioNTech, Sinovac          24918773.0
# 858   Turkey  2021-05-08  Pfizer/BioNTech, Sinovac          24853353.0
# 879   Turkey  2021-05-07  Pfizer/BioNTech, Sinovac          24691044.0
#
#      people_vaccinated  people_fully_vaccinated  \
# 51          14947740.0               10825003.0
# 104         14895052.0               10792375.0
# 196         14814316.0               10747682.0
# 307         14732527.0               10669750.0
# 415         14711273.0               10637602.0
# 468         14660551.0               10518123.0
# 664         14618167.0               10399911.0
# 673         14585980.0               10332793.0
# 858         14545524.0               10307829.0
# 879         14476881.0               10214163.0
#
#                             source_url
# 51   https://covid19asi.saglik.gov.tr/
# 104  https://covid19asi.saglik.gov.tr/
# 196  https://covid19asi.saglik.gov.tr/
# 307  https://covid19asi.saglik.gov.tr/
# 415  https://covid19asi.saglik.gov.tr/
# 468  https://covid19asi.saglik.gov.tr/
# 664  https://covid19asi.saglik.gov.tr/
# 673  https://covid19asi.saglik.gov.tr/
# 858  https://covid19asi.saglik.gov.tr/
# 879  https://covid19asi.saglik.gov.tr/

# %% [markdown]
# ## Israel <a class="anchor" id="Israel"></a>

# %%
Israel = allCountriesGitHub[allCountriesGitHub["location"] == "Israel"]
Israel.shape
# Out:
# (149, 7)

# %%
Israel[:10]
# Out:
#     location        date                   vaccine  total_vaccinations  \
# 27    Israel  2021-05-16  Moderna, Pfizer/BioNTech          10529230.0
# 86    Israel  2021-05-15  Moderna, Pfizer/BioNTech          10527792.0
# 158   Israel  2021-05-14  Moderna, Pfizer/BioNTech          10527498.0
# 289   Israel  2021-05-13  Moderna, Pfizer/BioNTech          10525421.0
# 423   Israel  2021-05-12  Moderna, Pfizer/BioNTech          10520219.0
# 539   Israel  2021-05-11  Moderna, Pfizer/BioNTech          10515342.0
# 627   Israel  2021-05-10  Moderna, Pfizer/BioNTech          10509316.0
# 719   Israel  2021-05-09  Moderna, Pfizer/BioNTech          10502058.0
# 810   Israel  2021-05-08  Moderna, Pfizer/BioNTech          10494691.0
# 885   Israel  2021-05-07  Moderna, Pfizer/BioNTech          10494102.0
#
#      people_vaccinated  people_fully_vaccinated  \
# 27           5432377.0                5096853.0
# 86           5431981.0                5095811.0
# 158          5431855.0                5095643.0
# 289          5431091.0                5094330.0
# 423          5429286.0                5090933.0
# 539          5427488.0                5087854.0
# 627          5425097.0                5084219.0
# 719          5422349.0                5079709.0
# 810          5419597.0                5075094.0
# 885          5419429.0                5074673.0
#
#                                                source_url
# 27   https://datadashboard.health.gov.il/COVID-19/general
# 86   https://datadashboard.health.gov.il/COVID-19/general
# 158  https://datadashboard.health.gov.il/COVID-19/general
# 289  https://datadashboard.health.gov.il/COVID-19/general
# 423  https://datadashboard.health.gov.il/COVID-19/general
# 539  https://datadashboard.health.gov.il/COVID-19/general
# 627  https://datadashboard.health.gov.il/COVID-19/general
# 719  https://datadashboard.health.gov.il/COVID-19/general
# 810  https://datadashboard.health.gov.il/COVID-19/general
# 885  https://datadashboard.health.gov.il/COVID-19/general

# %% [markdown]
# ## All countries
# number times reporting data

# %%
allCountriesGitHubCount = allCountriesGitHub["location"].value_counts()
allCountriesGitHubCount = allCountriesGitHubCount.reset_index()
allCountriesGitHubCount.index += 1   
# show number times reported top 100
allCountriesGitHubCount[100:140]
# Out:
#                                 index  location
# 101                           Nigeria        37
# 102               Trinidad and Tobago        36
# 103                    Cayman Islands        36
# 104                           Namibia        35
# 105                           Georgia        34
# 106                       Saint Lucia        34
# 107                             Aruba        32
# 108                            Guinea        32
# 109                   North Macedonia        31
# 110                            Rwanda        31
# 111                          Suriname        29
# 112                         Palestine        27
# 113                            Cyprus        27
# 114                             Nepal        26
# 115                        Costa Rica        24
# 116                         Greenland        24
# 117                            Sweden        23
# 118                          Dominica        22
# 119                           Bermuda        21
# 120                            Zambia        21
# 121                         Singapore        21
# 122                           Grenada        20
# 123                        Kazakhstan        20
# 124                       Netherlands        19
# 125                           Andorra        19
# 126                          Ethiopia        19
# 127                  French Polynesia        17
# 128                             Kenya        16
# 129                              Iran        15
# 130                            Jordan        15
# 131                             Ghana        15
# 132                          Pakistan        15
# 133                     New Caledonia        14
# 134                      Sierra Leone        13
# 135               Antigua and Barbuda        12
# 136  Saint Vincent and the Grenadines        12
# 137                   Northern Cyprus        11
# 138                          Guernsey        11
# 139                            Guyana        11
# 140             Saint Kitts and Nevis        10

# %%
#Latest reported
allCountriesGitHub[:10]
# Out:
#        location        date  \
# 1      Zimbabwe  2021-05-16
# 2   South Korea  2021-05-16
# 3         Qatar  2021-05-16
# 4        Brazil  2021-05-16
# 5    Azerbaijan  2021-05-16
# 6        Taiwan  2021-05-16
# 7        Latvia  2021-05-16
# 8       Curacao  2021-05-16
# 9        Cyprus  2021-05-16
# 10      Ukraine  2021-05-16
#
#                                                           vaccine  \
# 1                                               Sinopharm/Beijing
# 2                             Oxford/AstraZeneca, Pfizer/BioNTech
# 3                                                 Pfizer/BioNTech
# 4                    Pfizer/BioNTech, Oxford/AstraZeneca, Sinovac
# 5                                     Oxford/AstraZeneca, Sinovac
# 6                                              Oxford/AstraZeneca
# 7   Pfizer/BioNTech, Moderna, Oxford/AstraZeneca, Johnson&Johnson
# 8                                        Pfizer/BioNTech, Moderna
# 9            Pfizer/BioNTech, Oxford/AstraZeneca, Johnson&Johnson
# 10                   Oxford/AstraZeneca, Sinovac, Pfizer/BioNTech
#
#     total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 1             796947.0           581615.0                 215332.0
# 2            4674151.0          3733806.0                 940345.0
# 3            2035475.0          1190700.0                 844775.0
# 4           52771668.0         35801333.0               16970335.0
# 5            1795049.0          1030831.0                 764218.0
# 6             194678.0                NaN                      NaN
# 7             503189.0           389036.0                 116770.0
# 8             123637.0            79747.0                  43890.0
# 9             434550.0           325648.0                 108902.0
# 10            958552.0           940158.0                  18394.0
#
#                                                                      source_url
# 1                       https://twitter.com/MoHCCZim/status/1394026036938092550
# 2                                                        http://ncv.kdca.go.kr/
# 3            https://covid19.moph.gov.qa/EN/Pages/Vaccination-Program-Data.aspx
# 4   https://qsprod.saude.gov.br/extensions/DEMAS_C19Vacina/DEMAS_C19Vacina.html
# 5                                                    https://koronavirusinfo.az
# 6                   https://www.cdc.gov.tw/Category/Page/9jFXNbCe-sFK9EImRRi2Og
# 7                     https://data.gov.lv/dati/eng/dataset/covid19-vakcinacijas
# 8                                                            https://bakuna.cw/
# 9       https://www.moh.gov.cy/moh/moh.nsf/All/0EFA027144C9E54AC22586BE0032B2F5
# 10                                          https://vaccination.covid19.gov.ua/

# %%
allCountriesGitHub.shape
# Out:
# (10631, 7)
