# %%
import pandas as pd
from datetime import date
dataset = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv')
#locations = dataset[['location', 'iso_code']].sample(3)
locationDict = {'location': ['Sweden','Denmark','Finland'],
        'iso_code': ["SWE","DAN","FIN"]}
locations = pd.DataFrame(locationDict, columns = ['location', 'iso_code'])
locations
# Out:
#   location iso_code
# 0   Sweden      SWE
# 1  Denmark      DAN
# 2  Finland      FIN

# %%
df = dataset[dataset.iso_code.isin(locations.iso_code)]
df
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 24762      FIN    Europe  ...           81.91                   0.938
# 24763      FIN    Europe  ...           81.91                   0.938
# 24764      FIN    Europe  ...           81.91                   0.938
# 24765      FIN    Europe  ...           81.91                   0.938
# 24766      FIN    Europe  ...           81.91                   0.938
# ...        ...       ...  ...             ...                     ...
# 67125      SWE    Europe  ...           82.80                   0.945
# 67126      SWE    Europe  ...           82.80                   0.945
# 67127      SWE    Europe  ...           82.80                   0.945
# 67128      SWE    Europe  ...           82.80                   0.945
# 67129      SWE    Europe  ...           82.80                   0.945
#
# [839 rows x 59 columns]

# %%
df = dataset[dataset.iso_code.isin({"DNK","SWE","FIN","NOR"})]
df
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 18828      DNK    Europe  ...            80.9                   0.940
# 18829      DNK    Europe  ...            80.9                   0.940
# 18830      DNK    Europe  ...            80.9                   0.940
# 18831      DNK    Europe  ...            80.9                   0.940
# 18832      DNK    Europe  ...            80.9                   0.940
# ...        ...       ...  ...             ...                     ...
# 67125      SWE    Europe  ...            82.8                   0.945
# 67126      SWE    Europe  ...            82.8                   0.945
# 67127      SWE    Europe  ...            82.8                   0.945
# 67128      SWE    Europe  ...            82.8                   0.945
# 67129      SWE    Europe  ...            82.8                   0.945
#
# [1641 rows x 59 columns]

# %%
location_ = {'location': ['Sweden','Denmark','Finland'],
        'iso_code': ["SWE","DAN","FIN"]}
df = pd.DataFrame(locations, columns = ['location', 'iso_code'])
df
# Out:
#   location iso_code
# 0   Sweden      SWE
# 1  Denmark      DAN
# 2  Finland      FIN
